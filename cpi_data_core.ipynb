# %%
import pandas as pd

from plot_utils import *

# %% [markdown]
# ## Индекс потребительских цен на товары и услуги

# %%
# данные на конец предыдущего месяца
df = pd.read_excel('./stats/ipc_mes_08-2025.xlsx', sheet_name=1, skiprows=3)
df = df.iloc[1:13]
df = df.drop(df.columns[1:10], axis=1)
df.columns.values[0] = 'месяц'

df
# Out:
#        месяц    2000    2001    2002    2003    2004    2005    2006    2007  \
# 1     январь  102.33  102.76  103.09  102.40  101.75  102.62  102.43  101.68
# 2    февраль  101.04  102.28  101.16  101.63  100.99  101.23  101.66  101.11
# 3       март  100.64  101.86  101.08  101.05  100.75  101.34  100.82  100.59
# 4     апрель  100.89  101.79  101.16  101.02  100.99  101.12  100.35  100.57
# 5        май  101.75  101.78  101.69  100.80  100.74  100.80  100.48  100.63
# 6       июнь  102.55  101.62  100.53  100.80  100.78  100.64  100.28  100.95
# 7       июль  101.79  100.45  100.72  100.71  100.92  100.46  100.67  100.87
# 8     август  100.98  100.01  100.09   99.59  100.42   99.86  100.19  100.09
# 9   сентябрь  101.32  100.60  100.40  100.34  100.43  100.25  100.09  100.79
# 10   октябрь  102.11  101.09  101.07  101.00  101.14  100.55  100.28  101.64
# 11    ноябрь  101.52  101.36  101.61  100.96  101.11  100.74  100.63  101.23
# ...

# %%
df_melted = df.melt(id_vars='месяц', var_name='год', value_name='ИПЦ')
df_melted = df_melted.dropna(subset=['ИПЦ'])

month_map = {
    'январь': 1, 'февраль': 2, 'март': 3, 'апрель': 4,
    'май': 5, 'июнь': 6, 'июль': 7, 'август': 8,
    'сентябрь': 9, 'октябрь': 10, 'ноябрь': 11, 'декабрь': 12
}
df_melted['month_num'] = df_melted['месяц'].map(month_map)
df_melted['год'] = df_melted['год'].astype(int)
df_melted['date'] = pd.to_datetime(df_melted['год'].astype(str) + '-' + df_melted['month_num'].astype(str) + '-01')

df_melted = df_melted.sort_values('date')
df_melted.head()
# Out:
#      месяц   год     ИПЦ  month_num       date
# 0   январь  2000  102.33          1 2000-01-01
# 1  февраль  2000  101.04          2 2000-02-01
# 2     март  2000  100.64          3 2000-03-01
# 3   апрель  2000  100.89          4 2000-04-01
# 4      май  2000  101.75          5 2000-05-01

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['ИПЦ'],
    xlabel="Дата",
    ylabel="Отношение к предыдущему месяцу (в процентах)",
    title=f"Индекс потребительских цен в России на товары и услуги (1991–2025)"
)
# Out:
# <div>                            <div id="b5171f35-8a82-42c8-9892-7cdd06f88025" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5171f35-8a82-42c8-9892-7cdd06f88025")) {                    Plotly.newPlot(                        "b5171f35-8a82-42c8-9892-7cdd06f88025",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %%
df_melted['factor'] = df_melted['ИПЦ'] / 100

# Накопленный индекс
df_melted['cumulative_cpi'] = df_melted['factor'].cumprod()

# ---- Нормализация к базовому году ----
base_date = pd.Timestamp('2000-01-01')
base_value = df_melted.loc[df_melted['date'] == base_date, 'cumulative_cpi'].values[0]
df_melted['cpi_2000'] = (df_melted['cumulative_cpi'] / base_value) * 100

# ---- Реальная ценность рубля ----
df_melted['real_ruble'] = 100 / df_melted['cpi_2000']

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['real_ruble'],
    xlabel="Дата",
    ylabel="Реальная покупательная способность (в ценах 1 января 2000 г.)",
    title="Покупательная способность рубля относительно базового уровня на товары и услуги (2000 = 1.0)"
)
# Out:
# <div>                            <div id="30ad7073-b54c-43da-9cae-02ab4edfcec2" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30ad7073-b54c-43da-9cae-02ab4edfcec2")) {                    Plotly.newPlot(                        "30ad7073-b54c-43da-9cae-02ab4edfcec2",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %% [markdown]
# ## Индекс потребительских цен на продовольственные товары

# %%
df = pd.read_excel('./stats/ipc_mes_08-2025.xlsx', sheet_name=2, skiprows=3)
df = df.iloc[1:13]
df = df.drop(df.columns[1:10], axis=1)
df.columns.values[0] = 'месяц'

df.head(12)
# Out:
#        месяц    2000    2001    2002    2003    2004    2005    2006    2007  \
# 1     январь  102.17  103.06  102.82  102.51  101.61  101.42  101.97  100.94
# 2    февраль  100.46  102.28  100.87  101.20  101.12  101.37  102.98  100.83
# 3       март  100.09  101.77  100.46  100.97  101.05  102.07  101.17  100.77
# 4     апрель  100.30  102.01  100.96  100.98  100.84  101.70  100.26  100.75
# 5        май  102.17  102.27  102.21  100.69  100.43  101.06  100.47  100.95
# 6       июнь  103.26  101.91   99.82  100.79  100.80  100.72  100.02  101.73
# 7       июль  101.75   99.74  100.43  100.41  101.01  100.27  100.89  101.42
# 8     август  100.29   98.97   98.92   98.59  100.11   98.95   99.45   99.40
# 9   сентябрь  100.60   99.75   99.27   99.82  100.04   99.34   99.37  101.02
# 10   октябрь  102.13  100.74  100.62  101.10  101.39  100.36   99.95  103.26
# 11    ноябрь  101.52  101.48  101.96  101.24  101.53  100.89  100.78  101.93
# ...

# %%
df_melted = df.melt(id_vars='месяц', var_name='год', value_name='ИПЦ')
df_melted = df_melted.dropna(subset=['ИПЦ'])

month_map = {
    'январь': 1, 'февраль': 2, 'март': 3, 'апрель': 4,
    'май': 5, 'июнь': 6, 'июль': 7, 'август': 8,
    'сентябрь': 9, 'октябрь': 10, 'ноябрь': 11, 'декабрь': 12
}
df_melted['month_num'] = df_melted['месяц'].map(month_map)
df_melted['год'] = df_melted['год'].astype(int)
df_melted['date'] = pd.to_datetime(df_melted['год'].astype(str) + '-' + df_melted['month_num'].astype(str) + '-01')

df_melted = df_melted.sort_values('date')
df_melted.head()
# Out:
#      месяц   год     ИПЦ  month_num       date
# 0   январь  2000  102.17          1 2000-01-01
# 1  февраль  2000  100.46          2 2000-02-01
# 2     март  2000  100.09          3 2000-03-01
# 3   апрель  2000   100.3          4 2000-04-01
# 4      май  2000  102.17          5 2000-05-01

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['ИПЦ'],
    xlabel="Дата",
    ylabel="Отношение к предыдущему месяцу (в процентах)",
    title=f"Индекс потребительских цен в России на продовольственные товары (1991–2025)"
)
# Out:
# <div>                            <div id="1a808eaa-f4f5-4405-b194-d21d9ff68e3b" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a808eaa-f4f5-4405-b194-d21d9ff68e3b")) {                    Plotly.newPlot(                        "1a808eaa-f4f5-4405-b194-d21d9ff68e3b",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %%
df_melted['factor'] = df_melted['ИПЦ'] / 100

# Накопленный индекс
df_melted['cumulative_cpi'] = df_melted['factor'].cumprod()

# ---- Нормализация к базовому году ----
base_date = pd.Timestamp('2000-01-01')
base_value = df_melted.loc[df_melted['date'] == base_date, 'cumulative_cpi'].values[0]
df_melted['cpi_2000'] = (df_melted['cumulative_cpi'] / base_value) * 100

# ---- Реальная ценность рубля ----
df_melted['real_ruble'] = 100 / df_melted['cpi_2000']
df_melted
# Out:
#        месяц   год     ИПЦ  month_num       date  factor cumulative_cpi  \
# 0     январь  2000  102.17          1 2000-01-01  1.0217         1.0217
# 1    февраль  2000  100.46          2 2000-02-01  1.0046         1.0264
# 2       март  2000  100.09          3 2000-03-01  1.0009       1.027324
# 3     апрель  2000   100.3          4 2000-04-01   1.003       1.030406
# 4        май  2000  102.17          5 2000-05-01  1.0217       1.052765
# ..       ...   ...     ...        ...        ...     ...            ...
# 303   апрель  2025  100.71          4 2025-04-01  1.0071      10.607076
# 304      май  2025  100.26          5 2025-05-01  1.0026      10.634654
# 305     июнь  2025  100.11          6 2025-06-01  1.0011      10.646352
# 306     июль  2025   99.36          7 2025-07-01  0.9936      10.578216
# 307   август  2025   99.09          8 2025-08-01  0.9909      10.481954
#
#         cpi_2000 real_ruble
# 0          100.0        1.0
# 1         100.46   0.995421
# ...

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['real_ruble'],
    xlabel="Дата",
    ylabel="Реальная покупательная способность (в ценах 1 января 2000 г.)",
    title="Покупательная способность рубля относительно базового уровня на продовольственные товары (2000 = 1.0)"
)
# Out:
# <div>                            <div id="84f56caf-a8cd-4777-a409-9967841e7a2b" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84f56caf-a8cd-4777-a409-9967841e7a2b")) {                    Plotly.newPlot(                        "84f56caf-a8cd-4777-a409-9967841e7a2b",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %% [markdown]
# ## Индекс потребительских цен на непродовольственные товары

# %%
df = pd.read_excel('./stats/ipc_mes_08-2025.xlsx', sheet_name=3, skiprows=3)
df = df.iloc[1:13]
df = df.drop(df.columns[1:10], axis=1)
df.columns.values[0] = 'месяц'

df.head(12)
# Out:
#        месяц    2000    2001    2002    2003    2004    2005    2006    2007  \
# 1     январь  102.17  101.35  101.23  101.08  100.51  100.37  100.41  100.40
# 2    февраль  101.32  101.34  100.77  100.88  100.42  100.35  100.45  100.33
# 3       март  101.38  101.25  100.68  100.81  100.44  100.39  100.42  100.38
# 4     апрель  101.49  100.87  100.77  100.63  100.58  100.51  100.28  100.40
# 5        май  101.09  100.87  101.19  100.58  100.77  100.43  100.41  100.35
# 6       июнь  100.83  100.59  101.13  100.54  100.67  100.31  100.34  100.30
# 7       июль  100.84  100.53  100.57  100.47  100.56  100.43  100.40  100.37
# 8     август  101.38  100.79  100.68  100.58  100.52  100.53  100.76  100.60
# 9   сентябрь  102.05  101.16  100.87  100.87  100.87  101.09  100.76  100.77
# 10   октябрь  101.89  101.31  100.91  100.96  100.74  100.71  100.61  100.86
# 11    ноябрь  101.47  101.06  100.86  100.84  100.67  100.63  100.56  100.86
# ...

# %%
df_melted = df.melt(id_vars='месяц', var_name='год', value_name='ИПЦ')
df_melted = df_melted.dropna(subset=['ИПЦ'])

month_map = {
    'январь': 1, 'февраль': 2, 'март': 3, 'апрель': 4,
    'май': 5, 'июнь': 6, 'июль': 7, 'август': 8,
    'сентябрь': 9, 'октябрь': 10, 'ноябрь': 11, 'декабрь': 12
}
df_melted['month_num'] = df_melted['месяц'].map(month_map)
df_melted['год'] = df_melted['год'].astype(int)
df_melted['date'] = pd.to_datetime(df_melted['год'].astype(str) + '-' + df_melted['month_num'].astype(str) + '-01')

df_melted = df_melted.sort_values('date')
df_melted.head()
# Out:
#      месяц   год     ИПЦ  month_num       date
# 0   январь  2000  102.17          1 2000-01-01
# 1  февраль  2000  101.32          2 2000-02-01
# 2     март  2000  101.38          3 2000-03-01
# 3   апрель  2000  101.49          4 2000-04-01
# 4      май  2000  101.09          5 2000-05-01

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['ИПЦ'],
    xlabel="Дата",
    ylabel="Отношение к предыдущему месяцу (в процентах)",
    title=f"Индекс потребительских цен в России на непродовольственные товары (1991–2025)"
)
# Out:
# <div>                            <div id="405985f2-cbde-4472-b9d8-61e9d9fb0518" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("405985f2-cbde-4472-b9d8-61e9d9fb0518")) {                    Plotly.newPlot(                        "405985f2-cbde-4472-b9d8-61e9d9fb0518",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %%
df_melted['factor'] = df_melted['ИПЦ'] / 100

# Накопленный индекс
df_melted['cumulative_cpi'] = df_melted['factor'].cumprod()

# ---- Нормализация к базовому году ----
base_date = pd.Timestamp('2000-01-01')
base_value = df_melted.loc[df_melted['date'] == base_date, 'cumulative_cpi'].values[0]
df_melted['cpi_2000'] = (df_melted['cumulative_cpi'] / base_value) * 100

# ---- Реальная ценность рубля ----
df_melted['real_ruble'] = 100 / df_melted['cpi_2000']
df_melted
# Out:
#        месяц   год     ИПЦ  month_num       date  factor cumulative_cpi  \
# 0     январь  2000  102.17          1 2000-01-01  1.0217         1.0217
# 1    февраль  2000  101.32          2 2000-02-01  1.0132       1.035186
# 2       март  2000  101.38          3 2000-03-01  1.0138       1.049472
# 3     апрель  2000  101.49          4 2000-04-01  1.0149       1.065109
# 4        май  2000  101.09          5 2000-05-01  1.0109       1.076719
# ..       ...   ...     ...        ...        ...     ...            ...
# 303   апрель  2025   99.93          4 2025-04-01  0.9993       6.356561
# 304      май  2025   99.87          5 2025-05-01  0.9987       6.348297
# 305     июнь  2025   99.97          6 2025-06-01  0.9997       6.346393
# 306     июль  2025  100.19          7 2025-07-01  1.0019       6.358451
# 307   август  2025  100.42          8 2025-08-01  1.0042       6.385156
#
#        cpi_2000 real_ruble
# 0         100.0        1.0
# 1        101.32   0.986972
# ...

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['real_ruble'],
    xlabel="Дата",
    ylabel="Реальная покупательная способность (в ценах 1 января 2000 г.)",
    title="Покупательная способность рубля относительно базового уровня на непродовольственные товары (2000 = 1.0)"
)
# Out:
# <div>                            <div id="3d207830-d5f7-42af-bd85-746c8337c071" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d207830-d5f7-42af-bd85-746c8337c071")) {                    Plotly.newPlot(                        "3d207830-d5f7-42af-bd85-746c8337c071",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %% [markdown]
# ## Индексы потребительских цен на услуги

# %%
df = pd.read_excel('./stats/ipc_mes_08-2025.xlsx', sheet_name=4, skiprows=3)
df = df.iloc[1:13]
df = df.drop(df.columns[1:10], axis=1)
df.columns.values[0] = 'месяц'

df.head(12)
# Out:
#        месяц    2000    2001    2002    2003    2004    2005    2006    2007  \
# 1     январь  103.37  104.63  107.47  104.42  104.13  108.78  106.17  104.71
# 2    февраль  102.97  104.27  102.73  104.16  101.63  102.23  101.01  102.60
# 3       март  101.45  103.44  103.70  101.67  100.56  101.22  100.72  100.57
# 4     апрель  102.14  102.80  102.40  101.78  101.99  100.82  100.58  100.51
# 5        май  101.34  101.76  100.97  101.47  101.38  100.79  100.60  100.49
# 6       июнь  103.02  102.53  101.64  101.22  100.89  100.92  100.68  100.61
# 7       июль  103.77  102.90  101.79  101.91  101.31  100.91  100.61  100.64
# 8     август  103.00  102.26  102.53  100.73  100.98  100.77  100.75  100.53
# 9   сентябрь  102.77  102.55  102.76  100.89  100.63  100.90  100.45  100.44
# 10   октябрь  102.40  101.91  102.51  100.80  101.20  100.69  100.41  100.13
# 11    ноябрь  101.58  101.47  101.85  100.40  100.83  100.61  100.48  100.58
# ...

# %%
df_melted = df.melt(id_vars='месяц', var_name='год', value_name='ИПЦ')
df_melted = df_melted.dropna(subset=['ИПЦ'])

month_map = {
    'январь': 1, 'февраль': 2, 'март': 3, 'апрель': 4,
    'май': 5, 'июнь': 6, 'июль': 7, 'август': 8,
    'сентябрь': 9, 'октябрь': 10, 'ноябрь': 11, 'декабрь': 12
}
df_melted['month_num'] = df_melted['месяц'].map(month_map)
df_melted['год'] = df_melted['год'].astype(int)
df_melted['date'] = pd.to_datetime(df_melted['год'].astype(str) + '-' + df_melted['month_num'].astype(str) + '-01')

df_melted = df_melted.sort_values('date')
df_melted.head()
# Out:
#      месяц   год     ИПЦ  month_num       date
# 0   январь  2000  103.37          1 2000-01-01
# 1  февраль  2000  102.97          2 2000-02-01
# 2     март  2000  101.45          3 2000-03-01
# 3   апрель  2000  102.14          4 2000-04-01
# 4      май  2000  101.34          5 2000-05-01

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['ИПЦ'],
    xlabel="Дата",
    ylabel="Отношение к предыдущему месяцу (в процентах)",
    title=f"Индекс потребительских цен в России на услуги (1991–2025)"
)
# Out:
# <div>                            <div id="dd6ce336-a49c-40d3-a196-e3baad1f6fff" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd6ce336-a49c-40d3-a196-e3baad1f6fff")) {                    Plotly.newPlot(                        "dd6ce336-a49c-40d3-a196-e3baad1f6fff",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...

# %%
df_melted['factor'] = df_melted['ИПЦ'] / 100

# Накопленный индекс
df_melted['cumulative_cpi'] = df_melted['factor'].cumprod()

# ---- Нормализация к базовому году ----
base_date = pd.Timestamp('2000-01-01')
base_value = df_melted.loc[df_melted['date'] == base_date, 'cumulative_cpi'].values[0]
df_melted['cpi_2000'] = (df_melted['cumulative_cpi'] / base_value) * 100

# ---- Реальная ценность рубля ----
df_melted['real_ruble'] = 100 / df_melted['cpi_2000']
df_melted
# Out:
#        месяц   год     ИПЦ  month_num       date  factor cumulative_cpi  \
# 0     январь  2000  103.37          1 2000-01-01  1.0337         1.0337
# 1    февраль  2000  102.97          2 2000-02-01  1.0297       1.064401
# 2       март  2000  101.45          3 2000-03-01  1.0145       1.079835
# 3     апрель  2000  102.14          4 2000-04-01  1.0214       1.102943
# 4        май  2000  101.34          5 2000-05-01  1.0134       1.117723
# ..       ...   ...     ...        ...        ...     ...            ...
# 303   апрель  2025  100.53          4 2025-04-01  1.0053      21.846532
# 304      май  2025  101.34          5 2025-05-01  1.0134      22.139276
# 305     июнь  2025  100.59          6 2025-06-01  1.0059      22.269898
# 306     июль  2025  102.69          7 2025-07-01  1.0269      22.868958
# 307   август  2025   99.38          8 2025-08-01  0.9938       22.72717
#
#         cpi_2000 real_ruble
# 0          100.0        1.0
# 1         102.97   0.971157
# ...

# %%
plot_2d_interactive(
    x=df_melted['date'],
    y=df_melted['real_ruble'],
    xlabel="Дата",
    ylabel="Реальная покупательная способность (в ценах 1 января 2000 г.)",
    title="Покупательная способность рубля относительно базового уровня на услуги (2000 = 1.0)"
)
# Out:
# <div>                            <div id="e467049a-4ac5-46b6-b469-c9cd5f450c00" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e467049a-4ac5-46b6-b469-c9cd5f450c00")) {                    Plotly.newPlot(                        "e467049a-4ac5-46b6-b469-c9cd5f450c00",                        [{"hovertemplate":"\u0414\u0430\u0442\u0430: %{x}<br>\u0417\u043d\u0430\u0447\u0435\u043d\u0438\u0435: %{y:.4f} <extra></extra>","line":{"color":"royalblue","width":2},"mode":"lines","x":["2000-01-01T00:00:00","2000-02-01T00:00:00","2000-03-01T00:00:00","2000-04-01T00:00:00","2000-05-01T00:00:00","2000-06-01T00:00:00","2000-07-01T00:00:00","2000-08-01T00:00:00","2000-09-01T00:00:00","2000-10-01T00:00:00","2000-11-01T00:00:00","2000-12-01T00:00:00","2001-01-01T00
# ...
