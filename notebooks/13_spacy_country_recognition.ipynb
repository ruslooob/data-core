# %%
import pandas as pd
import time
from core.spacy_country_recognition import CountryRecognizer

# %%
df = pd.read_csv('../data/events/3_countries/2000-2025.csv')

df.head()
# Out:
#    date_start date_end                                              event  \
# 0  2000-01-01      NaN                    Деноминация белорусского рубля;
# 1  2000-01-01      NaN  В связи с «проблемой-2000», в Иране объявлен н...
# 2  2000-01-01      NaN  Вступление в силу закона в Великобритании, сог...
# 3  2000-01-02      NaN  крушение украинского сухогруза типа «река-море...
# 4  2000-01-03      NaN  Обстрел из гранатомёта территории российского ...
#
#                                            loc  \
# 0                                           []
# 1                                    ['Иране']
# 2                           ['Великобритании']
# 3  ['Тикси', 'Николаев', 'Камбоджи', 'Туапсе']
# 4                         ['Ливане', 'Бейрут']
#
#                                       norm_loc
# 0                                           []
# 1                                     ['Иран']
# 2                           ['Великобритания']
# 3  ['Тикси', 'Николаев', 'Камбоджа', 'Туапсе']
# 4                         ['Ливана', 'Бейрут']

# %%
recognizer = CountryRecognizer()

start = time.time()
df["country"] = recognizer.match_locations_series(df["event"])
elapsed = time.time() - start

recognized = df["country"].notna().sum()
print(f"Время:     {elapsed:.2f} с")
print(f"Опознано:  {recognized} / {len(df)} строк ({recognized / len(df) * 100:.1f}%)")
df.head(10)
# Out:
# Время:     30.13 с
# Опознано:  3900 / 5630 строк (69.3%)
#    date_start date_end                                              event  \
# 0  2000-01-01      NaN                    Деноминация белорусского рубля;
# 1  2000-01-01      NaN  В связи с «проблемой-2000», в Иране объявлен н...
# 2  2000-01-01      NaN  Вступление в силу закона в Великобритании, сог...
# 3  2000-01-02      NaN  крушение украинского сухогруза типа «река-море...
# 4  2000-01-03      NaN  Обстрел из гранатомёта территории российского ...
# 5  2000-01-03      NaN  Победа коалиции социал-демократов-социал-либер...
# 6  2000-01-08      NaN  первая Рождественская литургия в Храме Христа ...
# 7  2000-01-09      NaN  Переизбрание Ислама Каримова президентом Респу...
# 8  2000-01-09      NaN  Проведение в трёх субъектах России повторных в...
# 9  2000-01-09      NaN  Вторая чеченская война: прорыв боевиков в Шали...
#
#                                                  loc  \
# 0                                                 []
# 1                                          ['Иране']
# 2                                 ['Великобритании']
# 3        ['Тикси', 'Николаев', 'Камбоджи', 'Туапсе']
# 4                               ['Ливане', 'Бейрут']
# 5                                       ['Хорватии']
# 6                             ['Московский', 'Руси']
# 7                          ['Республики Узбекистан']
# 8  ['России', 'Московской', 'Тверской', 'Новосиби...
# 9               ['Шали', 'Аргун', 'Шали', 'Аргуном']
#
#                                             norm_loc              country
# 0                                                 []            [BELARUS]
# 1                                           ['Иран']               [IRAN]
# 2                                 ['Великобритания']                 [UK]
# 3        ['Тикси', 'Николаев', 'Камбоджа', 'Туапсе']  [UKRAINE, CAMBODIA]
# 4                               ['Ливана', 'Бейрут']             [RUSSIA]
# 5                                       ['Хорватия']            [CROATIA]
# 6                             ['Московский', 'Русь']             [RUSSIA]
# 7                          ['Республика Узбекистан']         [UZBEKISTAN]
# 8  ['Россия', 'Московская', 'Тверская', 'Новосиби...             [RUSSIA]
# 9                                  ['Шаль', 'Аргун']             [RUSSIA]
