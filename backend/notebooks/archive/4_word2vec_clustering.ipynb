# %%
import re
import warnings
from collections import Counter

import nltk
import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords

warnings.filterwarnings("ignore")

nltk.download('stopwords')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('russian'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ruslan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ruslan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
def tokenize(text):
    """Токенизирует входящий текст"""
    text = text.lower()
    text = re.sub(r'[^а-яa-z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t not in stop_words]
    return tokens


df = pd.read_csv("../../data/events/2_struct/2000-2025.csv")  #
df["tokens"] = df["event"].apply(tokenize)
df.head()
# Out:
#    date_start date_end                                              event  \
# 0  2000-01-01      NaN                    Деноминация белорусского рубля;
# 1  2000-01-01      NaN  В связи с «проблемой-2000», в Иране объявлен н...
# 2  2000-01-01      NaN  Вступление в силу закона в Великобритании, сог...
# 3  2000-01-02      NaN  крушение украинского сухогруза типа «река-море...
# 4  2000-01-03      NaN  Обстрел из гранатомёта территории российского ...
#
#                                               tokens
# 0                 [деноминация, белорусского, рубля]
# 1  [связи, проблемой, иране, объявлен, нерабочий,...
# 2  [вступление, силу, закона, великобритании, сог...
# 3  [крушение, украинского, сухогруза, типа, рекам...
# 4  [обстрел, гранатомта, территории, российского,...

# %%
from gensim.models import Word2Vec

corpus = df["tokens"].tolist()

total_words = sum(len(tokens) for tokens in corpus)
print(f"Всего слов (токенов): {total_words}")

unique_words = len(set(word for tokens in corpus for word in tokens))
print(f"Уникальных слов: {unique_words}")

corpus[0]
# Out:
# Всего слов (токенов): 61958
# Уникальных слов: 17583
# ['деноминация', 'белорусского', 'рубля']

# %%
def vectorize(tokens, model):
    """
    Преобразует список токенов в один вектор события на основе обученной модели Word2Vec.
    """
    vectors = [model.wv[w] for w in tokens if w in model.wv]
    if not vectors:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)  # вопросы по поводу среднего, почему берем именно среднее?


model = Word2Vec(
    sentences=corpus,
    vector_size=100,  # размерность векторов
    window=5,
    min_count=2,
    sg=1,  # skip-gram,
    epochs=20,
    seed=42
)
df["vector"] = df["tokens"].apply(lambda t: vectorize(t, model))
X = np.vstack(df["vector"].values)
X.shape
# Out:
# (5647, 100)

# %%
from sklearn.preprocessing import normalize
import hdbscan

# 1️⃣ Нормализуем векторы (каждый до единичной длины)
X_norm = normalize(X, norm='l2')

# 2️⃣ Обучаем HDBSCAN с метрикой cosine
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=10,
    min_samples=3,
    metric='cosine',
    algorithm='generic',
)

# 3️⃣ Кластеризация
labels = clusterer.fit_predict(X_norm)
df["cluster"] = labels

# 4️⃣ Проверяем результат
print("Количество кластеров:", len(set(labels)) - (1 if -1 in labels else 0))
# Out:
# Количество кластеров: 51

# %%
for cluster_id in sorted(df["cluster"].unique()):
    subset = df[df["cluster"] == cluster_id]
    tokens = [t for tokens in subset["tokens"] for t in tokens]
    common = Counter(tokens).most_common(10)
    print(f"\nКластер {cluster_id}: {[w for w, _ in common]}")
# Out:
# Кластер -1: ['выборы', 'сша', 'президента', 'россии', 'президент', 'победу', 'года', 'парламентские', 'человек', 'выборов']
#
# Кластер 0: ['дипломатические', 'отношения', 'установили', 'разорвала', 'отношение', 'узбекистан', 'установлены', 'бутан', 'украина', 'арменией']
#
# Кластер 1: ['перепись', 'населения', 'прошла', 'эстонии', 'украине', 'всероссийская', 'республике', 'болгарии', 'литве', 'великобритании']
#
# Кластер 2: ['санкций', 'против', 'россии', 'принятие', 'пакета', 'пакет', 'принят', 'первого', 'второго', 'третьего']
#
# Кластер 3: ['церемония', 'состоялась', 'вручения', 'прошла', 'лосанджелесе', 'оскар', 'лучшим', 'фильмом', 'папы', 'римского']
#
# Кластер 4: ['игр', 'олимпийских', 'летних', 'года', 'зимних', 'церемония', 'токио', 'проведение', 'столицей', 'открытия']
#
# Кластер 5: ['день', 'единый', 'голосования', 'россии', 'прошл', 'официальнй', 'траура', 'погибшим', 'апл', 'курск']
#
# Кластер 6: ['оон', 'безопасности', 'совет', 'резолюцию', 'принял', 'единогласно', 'вывода', 'израильских', 'ливана', 'совета']
#
# Кластер 7: ['православной', 'церкви', 'собор', 'русской', 'украине', 'церковь', 'архиерейский', 'патриархата', 'автокефалии', 'православная']
#
# Кластер 8: ['форум', 'казахстана', 'россии', 'межрегионального', 'сотрудничества', 'россия', 'казахстан', 'приграничных', 'регионов', 'i']
#
# Кластер 9: ['президента', 'российской', 'федерации', 'путина', 'владимира', 'россии', 'рф', 'указом', 'дмитрия', 'медведева']
#
# Кластер 10: ['силу', 'россии', 'закон', 'вступил', 'договор', 'федерации', 'российской', 'россией', 'подписан', 'государственная']
#
# Кластер 11: ['протеста', 'против', 'начались', 'массовые', 'акции', 'протесты', 'беспорядки', 'оппозиции', 'день', 'иране']
#
# Кластер 12: ['начало', 'войны', 'протестных', 'акций', 'гражданской', 'столкновений', 'властями', 'против', 'судебного', 'процесса']
#
# Кластер 13: ['россии', 'введн', 'fox', 'kids', 'игорных', 'блокировка', 'мессенджера', 'гражданам', 'разрешено', 'открывать']
#
# Кластер 14: ['игры', 'олимпийские', 'летние', 'зимние', 'юношеские', 'прошли', 'паралимпийские', 'всемирные', 'кочевников', 'азиатские']
#
# Кластер 15: ['стала', 'европейского', 'союза', 'совета', 'государствомпредседателем', 'председателем', 'обсе', 'испания', 'польша', 'совете']
#
# Кластер 16: ['форум', 'международный', 'экономический', 'астана', 'казахстан', 'россия', 'петербургский', 'всемирный', 'санктпетербург', 'й']
#
# Кластер 17: ['саммит', 'g', 'государств', 'глав', 'состоялся', 'брикс', 'й', 'снг', 'нато', 'атэс']
#
# Кластер 18: ['президент', 'подписал', 'закон', 'россии', 'владимир', 'путин', 'указ', 'сша', 'казахстана', 'года']
#
# Кластер 19: ['й', 'кинофестиваль', 'международный', 'конкурс', 'евровидение', 'латвия', 'музыки', 'московский', 'молодых', 'исполнителей']
#
# Кластер 20: ['области', 'губернатором', 'переизбран', 'избран', 'субъектах', 'россии', 'глав', 'владимир', 'регионов', 'прошли']
#
# Кластер 21: ['года', 'пост', 'премьерминистра', 'занял', 'назначен', 'председателя', 'боснии', 'марта', 'мая', 'апреля']
#
# Кластер 22: ['премьерминистром', 'стал', 'новым', 'лидер', 'назначен', 'партии', 'армении', 'премьерминистра', 'отставку', 'греции']
#
# Кластер 23: ['отставку', 'президента', 'президент', 'обязанности', 'подал', 'премьерминистр', 'ушл', 'страны', 'стал', 'исполняющим']
#
# Кластер 24: ['победу', 'чемпионат', 'одержала', 'сборная', 'мира', 'россии', 'й', 'зачте', 'состоялся', 'европы']
#
# Кластер 25: ['проведение', 'выборов', 'президентских', 'парламентских', 'тура', 'первого', 'кыргызстане', 'грузии', 'второго', 'досрочных']
#
# Кластер 26: ['должность', 'президента', 'вступил', 'вступление', 'вступила', 'швейцарии', 'кыргызстана', 'чехии', 'румынии', 'польши']
#
# Кластер 27: ['должность', 'президент', 'вступил', 'новый', 'египта', 'абхазии', 'вступила', 'франции', 'франсуа', 'олланд']
#
# Кластер 28: ['вступил', 'должность', 'президента', 'года', 'января', 'мая', 'декабря', 'леви', 'мванаваса', 'замбии']
#
# Кластер 29: ['вступил', 'должность', 'премьерминистра', 'года', 'июня', 'августа', 'имангали', 'тасмагамбетов', 'казахстана', 'байрам']
#
# Кластер 30: ['й', 'чемпионат', 'мира', 'хоккею', 'казахстан', 'россия', 'мячом', 'водным', 'видам', 'спорта']
#
# Кластер 31: ['чемпионат', 'мира', 'европы', 'гимнастике', 'хоккею', 'атлетике', 'фигурному', 'катанию', 'лгкой', 'германия']
#
# Кластер 32: ['чемпионат', 'россия', 'мира', 'москва', 'биатлону', 'конькобежному', 'спорту', 'летнему', 'уфа', 'европы']
#
# Кластер 33: ['президентом', 'избран', 'венгрии', 'избрана', 'литвы', 'новым', 'турции', 'ахмет', 'сезер', 'ференц']
#
# Кластер 34: ['вошла', 'купюра', 'номиналом', 'рублей', 'деноминация', 'оборот', 'белорусских', 'красный', 'белорусского', 'рубля']
#
# Кластер 35: ['windows', 'microsoft', 'server', 'операционную', 'систему', 'компания', 'выход', 'выпустила', 'поддержки', 'ос']
#
# Кластер 36: ['й', 'шаттла', 'полт', 'шаттл', 'старт', 'программе', 'спейс', 'sts', 'экипаж', 'продолжение']
#
# Кластер 37: ['победу', 'парламентских', 'одержала', 'партия', 'выборов', 'выборах', 'проведение', 'туре', 'президента', 'досрочных']
#
# Кластер 38: ['выборы', 'президентские', 'избран', 'президентом', 'парламентские', 'мохамед', 'абдуллахи', 'парагвае', 'парагвая', 'орасио']
#
# Кластер 39: ['союз', 'экипаж', 'корабля', 'сша', 'космического', 'тма', 'посадки', 'космический', 'приземление', 'старта']
#
# Кластер 40: ['космодрома', 'байконур', 'ракетыносителя', 'ракетаноситель', 'помощью', 'запущена', 'стартовала', 'запуск', 'протонм', 'спутником']
#
# Кластер 41: ['человек', 'погибли', 'результате', 'человека', 'погибло', 'получили', 'ранения', 'ранены', 'около', 'землетрясение']
#
# Кластер 42: ['война', 'вторая', 'чеченская', 'вертолт', 'человек', 'погибли', 'получили', 'ранения', 'афганистане', 'районе']
#
# Кластер 43: ['тур', 'выборов', 'президентских', 'первый', 'второй', 'парламентских', 'прошл', 'состоялся', 'республике', 'македонии']
#
# Кластер 44: ['выборы', 'партия', 'парламентские', 'мест', 'большинство', 'получила', 'правящая', 'консервативная', 'парламенте', 'удержала']
#
# Кластер 45: ['выборы', 'парламентские', 'партия', 'победу', 'одержала', 'правящая', 'оппозиционная', 'предварительным', 'данным', 'коалиция']
#
# Кластер 46: ['выборы', 'победу', 'одержал', 'президентские', 'действующий', 'президент', 'президента', 'предварительным', 'данным', 'парламентские']
#
# Кластер 47: ['второй', 'тур', 'победу', 'выборов', 'одержал', 'президентских', 'президента', 'выборы', 'одержала', 'действующий']
#
# Кластер 48: ['президентские', 'выборы', 'парламентские', 'финляндии', 'мальдивах', 'мадагаскаре', 'повторные', 'чили', 'ливане', 'бразилии']
#
# Кластер 49: ['парламентские', 'выборы', 'досрочные', 'австрии', 'молдове', 'иордании', 'косове', 'исландии', 'македонии', 'словении']
#
# Кластер 50: ['парламентские', 'выборы', 'островах', 'науру', 'белоруссии', 'литве', 'камеруне', 'мальдивах', 'узбекистане', 'венесуэле']

# %%
print("==================== События по кластерам ====================")
for cluster_id in sorted(df["cluster"].unique()):
    subset = df[df["cluster"] == cluster_id]

    print(f"🟩 Кластер {cluster_id} ({len(subset)} событий)")
    for event in subset["event"].head(10):  # показываем первые 10 событий
        print(f"  - {event}")

    tokens = [t for tokens in subset["tokens"] for t in tokens]
    common = [w for w, _ in Counter(tokens).most_common(10)]
    print(f"  🗝️ Ключевые слова: {common}")
# Out:
# ==================== События по кластерам ====================
# 🟩 Кластер -1 (3530 событий)
#   - В связи с «проблемой-2000», в Иране объявлен нерабочий день;
#   - Вступление в силу закона в Великобритании, согласно которому вес всех продуктов, имеющихся в продаже, обозначается в метрической системе, а не в традиционных для страны унциях и фунтах.
#   - Обстрел из гранатомёта территории российского посольства в Ливане, Бейрут;
#   - Победа коалиции социал-демократов-социал-либералов, вместе с блоком из четырёх других партий (во главе с Крестьянской партией) на парламентских выборах в Хорватии, набравших две трети голосов в парламенте, что в дальнейшем позволило изменить конституцию и превратить республику из полу-президентской в парламентскую.
#   - первая Рождественская литургия в Храме Христа Спасителя. Литургию отслужил Патриарх Московский и всея Руси Алексий II.
#   - Переизбрание Ислама Каримова президентом Республики Узбекистан (91,9 % голосов избирателей);
#   - Вторая чеченская война: прорыв боевиков в Шали и Аргун. Контроль федеральных сил над Шали был восстановлен 11 января, над Аргуном — 13 января.
#   - Демонстрация более 100 000 израильтян против возвращения Голанских высот в Тель-Авиве, Сирия;
#   - вынесение приговора членам одной из самых жестоких ОПГ новейшей криминальной истории России — «Слоновской ОПГ».
#   - на пост президента Гватемалы назначен Альфонсо Портильо Кабрера.
#   🗝️ Ключевые слова: ['выборы', 'сша', 'президента', 'россии', 'президент', 'победу', 'года', 'парламентские', 'человек', 'выборов']
# 🟩 Кластер 0 (34 событий)
#   - Узбекистан и Мьянма установили дипломатические отношения.
#   - Узбекистан и Коста-Рика установили дипломатические отношения.
#   - Узбекистан и Парагвай установили дипломатические отношения.
#   - Армения, Бруней и Буркина-Фасо установили дипломатические отношения.
#   - Установлены дипломатические отношение между Восточным Тимором, Россией и США.
#   - Узбекистан и Ангола установили дипломатические отношения.
#   - Армения и Тунис установили дипломатические отношения.
#   - Вьетнам и Восточный Тимор установили дипломатические отношения.
#   - Австралия и Бутан установили дипломатические отношения.
#   - Россия и Сент-Винсент и Гренадины установили дипломатические отношения.
#   🗝️ Ключевые слова: ['дипломатические', 'отношения', 'установили', 'разорвала', 'отношение', 'узбекистан', 'установлены', 'бутан', 'украина', 'арменией']
# 🟩 Кластер 1 (15 событий)
#   - в Эстонии прошла перепись населения.
#   - В Болгарии прошла перепись населения.
#   - в Литве прошла перепись населения .
#   - В Великобритании прошла перепись населения.
#   - на Украине прошла перепись населения.
#   - в Румынии прошла перепись населения.
#   - в России прошла перепись населения.
#   - в Беларуси прошла перепись населения.
#   - Всероссийская перепись населения.
#   - начало переписи населения в Эстонии.
#   🗝️ Ключевые слова: ['перепись', 'населения', 'прошла', 'эстонии', 'украине', 'всероссийская', 'республике', 'болгарии', 'литве', 'великобритании']
# 🟩 Кластер 2 (18 событий)
#   - Принятие первого пакета санкций против России.
#   - Принятие второго пакета санкций против России.
#   - Принятие третьего пакета санкций против России.
#   - Принятие четвертого пакета санкций против России.
#   - Принятие пятого пакета санкций против России.
#   - Принятие шестого пакета санкций против России.
#   - Принятие седьмого пакета санкций против России.
#   - Принятие 8 пакета санкций против России.
#   - Принят 9 пакет санкций против России.
#   - Принятие 10 пакета санкций против России.
#   🗝️ Ключевые слова: ['санкций', 'против', 'россии', 'принятие', 'пакета', 'пакет', 'принят', 'первого', 'второго', 'третьего']
# 🟩 Кластер 3 (19 событий)
#   - В Лос-Анджелесе состоялась 44-я церемония вручения премий «Грэмми».
#   - в Лос-Анджелесе состоялась 74-я церемония вручения наград премии «Оскар» за заслуги в области кинематографа за 2001 год. Лучшим фильмом стала драма «Игры разума».
#   - прошла церемония «крещения» морского суперлайнера «Queen Mary 2».
#   - на кинофестивале Sundance Film Festival состоялась премьера фильма ужасов «Пила: Игра на выживание».
#   - прошла 66-я церемония вручения кинопремии «Золотой глобус».
#   - в Голливуде состоялась церемония вручения кинопремии «Оскар» за 2008 год. Лучшим фильмом года признан «Миллионер из трущоб».
#   - в Лондоне состоялась премьера нового мюзикла Эндрю Ллойда Уэббера, сиквела мюзикла «Призрак Оперы» — «Любовь не умрёт никогда».
#   - в Лос-Анджелесе (США) состоялась 83-я церемония вручения премий Оскар. Лучшим фильмом года Американская киноакадемия признала картину «Король говорит!».
#   - на телеканале HBO состоялась премьера сериала «Игра престолов».
#   - интронизация папы римского Франциска.
#   🗝️ Ключевые слова: ['церемония', 'состоялась', 'вручения', 'прошла', 'лосанджелесе', 'оскар', 'лучшим', 'фильмом', 'папы', 'римского']
# 🟩 Кластер 4 (21 событий)
#   - проведение зимних Игр Доброй воли в Лейк-Плэсиде.
#   - состоялась церемония открытия XXVII летних Олимпийских игр в Сиднее, Австралия.
#   - Прошла церемония закрытия XXVII летних Олимпийских игр;
#   - Пекин объявлен столицей летних Олимпийских игр 2008 года.
#   - на сессии МОК в Гватемале Сочи выбран местом проведения XXII зимних Олимпийских игр 2014 года.
#   - закончился приём заявок на проведение Летних Олимпийских игр 2016 года. Заявки подали Баку, Токио, Доха, Мадрид, Прага, Чикаго и Рио-де-Жанейро.
#   - состоялось закрытие XXIX Олимпийских игр в Пекине.
#   - Официальная церемония открытия Международного года астрономии.
#   - Рио-де-Жанейро выбран местом проведения XXXI Летних Олимпийских игр.
#   - на предолимпийской сессии в Ванкувере (Канада) выбраны столицы Летних юношеских Олимпийских игр 2014 года и Зимних Юношеских Олимпийских игр 2016 года.
#   🗝️ Ключевые слова: ['игр', 'олимпийских', 'летних', 'года', 'зимних', 'церемония', 'токио', 'проведение', 'столицей', 'открытия']
# 🟩 Кластер 5 (18 событий)
#   - Официальнй день траура в России по погибшим на АПЛ "Курск".
#   - в России прошёл первый Единый день голосования.
#   - второй Единый день голосования.
#   - Десятый Единый день голосования в России.
#   - Единый день голосования (Россия).
#   - Единый день голосования в России.
#   - Единый день голосования в России.
#   - Единый день голосования в России.
#   - единый день голосования в России.
#   - единый день голосования в России.
#   🗝️ Ключевые слова: ['день', 'единый', 'голосования', 'россии', 'прошл', 'официальнй', 'траура', 'погибшим', 'апл', 'курск']
# 🟩 Кластер 6 (14 событий)
#   - Завершение вывода израильских войск из Ливана. Израиль выполнил, таким образом, резолюцию № 425 Совета Безопасности ООН от 1978 г., требовавшую вывода израильских сил из Ливана.
#   - Совет Безопасности ООН принял резолюцию № 1315 по созданию Специального суда по Сьерра-Леоне.
#   - Резолюцией № A/RES/52/2 Генеральной Ассамблеи ООН принята Декларация тысячелетия Организации Объединённых Наций.
#   - Совет Безопасности ООН принял резолюцию № 1333, вводящую запрет на продажу оружия и авиасообщение с режимом талибов в Афганистане, оказывающим поддержку международному терроризму.
#   - Совет Безопасности ООН единогласно принял резолюцию № 1367, которой постановил прекратить действие санкции против Югославии.
#   - Совет Безопасности ООН принял резолюцию № 1372 о борьбе с терроризмом.
#   - в соответствии с резолюцией № 1386 Совета Безопасности ООН были созданы Международные силы по поддержанию безопасности, действующий на территории Афганистана.
#   - Совет Безопасности ООН единогласно проголосовал за наложение санкций на экстремистскую организацию Аль-Каида и движение Талибан.
#   - Швейцария принята в члены ООН.
#   - Совет Безопасности ООН единогласно принял резолюцию № 1440, осуждающую захват заложников в Москве.
#   🗝️ Ключевые слова: ['оон', 'безопасности', 'совет', 'резолюцию', 'принял', 'единогласно', 'вывода', 'израильских', 'ливана', 'совета']
# 🟩 Кластер 7 (13 событий)
#   - в Москве в храме Христа Спасителя открылся юбилейный архиерейский собор Русской Православной Церкви.
#   - внеочередной Архиерейский собор Русской православной церкви. Поместный собор Русской православной церкви избрал нового Патриарха Московского и всея Руси. Им стал Кирилл.
#   - празднование православной Пасхи.
#   - Архиерейский собор Русской православной церкви (Храм Христа Спасителя, Москва, Россия).
#   - Архиерейский собор Русской православной церкви (Москва, Россия).
#   - митрополит Феогност включён в Собор Московских святителей.
#   - Константинопольский патриархат вмешался в церковную ситуацию на Украине: патриарх Варфоломей отправил на Украину двоих экзархов, де-факто запустив процесс создания на Украине автокефальной церкви на основе «Киевского патриархата». РПЦ расценила эти действия как раскол Православной церкви.
#   - Принят закон «О порядке формирования Совета Федерации». Ранее, 29 июля, в соответствии с этим были внесены поправки в закон «Об общих принципах организации законодательных (представительных) и исполнительных органов государственной власти субъектов РФ», а 4 августа — в закон «Об общих принципах организации местного самоуправления в РФ».
#   - подписан Ниццкий договор, который внёс изменения в Маастрихтский договор (или Договор о Европейском союзе), а также Римский договор (или Договор о создании Европейского сообщества). Этот договор стал следующим шагом в процессе дальнейшего реформирования Евросоюза. Он содержал статьи и декларации, протоколы и прочие приложения .
#   - в Германии вступил в силу закон о зарегистрированных гражданских партнёрствах.
#   - На Украине вступил в силу новый Уголовный кодекс, в котором высшая мера наказания заменена пожизненным заключением.
#   - вступил в силу Земельный кодекс Российской Федерации.
#   - В России вступил в силу закон «О государственном пенсионном обеспечении в Российской Федерации».
#   - Вступил в силу новый Трудовой кодекс Российской Федерации.
#   - в России вступил в силу закон «О лицензировании отдельных видов деятельности».
#   - ДКБ преобразована в полноценную международную организацию — Организацию договора о коллективной безопасности (ОДКБ). В неё вошли Россия, Армения, Белоруссия, Казахстан, Кыргызстан, Таджикистан и Узбекистан.
#   🗝️ Ключевые слова: ['силу', 'россии', 'закон', 'вступил', 'договор', 'федерации', 'российской', 'россией', 'подписан', 'государственная']
# 🟩 Кластер 11 (24 событий)
#   - Скоординированный общемировой день протеста против готовившегося вторжения коалиции, возглавляемой США, в Ирак. Демонстрации, проведённые в этот день, были частью протестов против Иракской войны, которые начались в 2002 году.
#   - Беспорядки в Косове.
#   - массовые протесты в исламском мире против публикации карикатур на пророка Мухаммеда (Карикатурный скандал 2005—2006 годов).
#   - Массовые беспорядки в Кишинёве.
#   - массовые беспорядки в Иране.
#   - состоялись акции протеста во многих городах России против платного основного образования.
#   - В Беларуси начались акции «молчаливого» протеста.
#   - В Белоруссии начались протесты против президентского указа № 222.
#   - 8 — многотысячные протесты мусульманок Боснии против запрета ношения хиджаба.
#   - В Ираке начались массовые протесты;???
#   🗝️ Ключевые слова: ['протеста', 'против', 'начались', 'массовые', 'акции', 'протесты', 'беспорядки', 'оппозиции', 'день', 'иране']
# 🟩 Кластер 12 (21 событий)
#   - начало конфликта между властями Автономной республикой Аджария (под управлением Аслана Абашидзе) и официальными грузинскими властями Тбилиси.
#   - начало восстания шиитов против оккупационных сил в Ираке, под руководством исламской организацией «Армия Махди». Начало первой битвы за Фаллуджу.
#   - Начало судебного процесса над террористом Нурпашой Кулаевым.
#   - начало судебного процесса над Саддамом Хусейном и рядом его сподвижников.
#   - Начало работы социальной сети Одноклассники.
#   - начало войны Израиля с Ливаном.
#   - Начало работы социальной сети ВКонтакте.
#   - Начало трансляции популярного мультсериала My Little Pony.
#   - Начало гражданской войны в Ливии между сторонниками и противниками Муамара Каддафи.
#   - Начало гражданской войны в Сирии.
#   🗝️ Ключевые слова: ['начало', 'войны', 'протестных', 'акций', 'гражданской', 'столкновений', 'властями', 'против', 'судебного', 'процесса']
# 🟩 Кластер 13 (16 событий)
#   - гражданам России разрешено открывать счета в иностранных банках.
#   - В России введён налог на добычу полезных ископаемых.
#   - Распоряжением Правительства России создано ФГУП «Почта России».
#   - В России завершили вещание телеканалы «Fox Kids» и «Fox Kids Play».
#   - в России разрешена деятельность игорных заведений только в специальных игорных зонах.
#   - аномальная жара и пожары в России.
#   - в России введён временный запрет на экспорт зерна по причине аномальной жары.
#   - Колумбия отменила визовый режим для граждан России.
#   - В России завершено преобразование милиции в полицию.
#   - Власти США сняли государственный флаг России со здания генконсульства РФ в Сан-Франциско и торгового представительства России в Вашингтоне.
#   🗝️ Ключевые слова: ['россии', 'введн', 'fox', 'kids', 'игорных', 'блокировка', 'мессенджера', 'гражданам', 'разрешено', 'открывать']
# 🟩 Кластер 14 (34 событий)
#   - в Брисбене прошли игры Доброй воли.
#   - летние Олимпийские игры в Афинах (Греция).
#   - в Турине (Италия) начались ХХ зимние Олимпийские игры (завершились 26 февраля).
#   - В Пекине открылись XXIX летние Олимпийские игры.
#   - первые Олимпийские игры роботов-андроидов 2010 (Харбин, Китай).
#   - Летние юношеские Олимпийские игры (Сингапур).
#   - I Зимние юношеские Олимпийские игры (Инсбрук, Австрия). Победу одержала сборная Германии.
#   - 30-е летние Олимпийские игры (Лондон, Великобритания).
#   - XIV летние Паралимпийские игры в Лондоне (Великобритания).
#   - XXII зимние Олимпийские игры (Сочи, Россия).
#   🗝️ Ключевые слова: ['игры', 'олимпийские', 'летние', 'зимние', 'юношеские', 'прошли', 'паралимпийские', 'всемирные', 'кочевников', 'азиатские']
# 🟩 Кластер 15 (15 событий)
#   - Испания стала Председателем Совета Европейского союза (до 30 июня 2002 года).
#   - Португалия стала председателем ОБСЕ.
#   - председателем Евросоюза становится Словения.
#   - Чехия стала Государством-председателем Совета Европейского союза.
#   - Швеция стала государством-председателем Совета Европейского союза.
#   - Испания стала государством-председателем Совета Европейского союза.
#   - Бельгия стала государством-председателем Совета Европейского союза.
#   - Венгрия стала государством-председателем Совета Европейского союза.
#   - Литва стала государством-председателем ОБСЕ.
#   - Польша стала государством-председателем Совета Европейского союза.
#   🗝️ Ключевые слова: ['стала', 'европейского', 'союза', 'совета', 'государствомпредседателем', 'председателем', 'обсе', 'испания', 'польша', 'совете']
# 🟩 Кластер 16 (27 событий)
#   - всероссийский форум «Здоровье и табак».
#   - XII Петербургский международный экономический форум.
#   - Петербургский международный экономический форум (Санкт-Петербург, Россия).
#   - I Международный кинофестиваль экшн-фильмов «Astana» (Астана, Казахстан).
#   - 41-й Всемирный экономический форум (Давос, Швейцария).
#   - IV Астанинский экономический форум (Астана, Казахстан).
#   - 7-й Всемирный исламский экономический форум (Астана, Казахстан).
#   - XIV Международный конкурс имени П. И. Чайковского (Москва, Россия).
#   - Петербургский международный экономический форум.
#   - II Международный кинофестиваль экшн-фильмов «Astana» (Астана, Казахстан).
#   🗝️ Ключевые слова: ['форум', 'международный', 'экономический', 'астана', 'казахстан', 'россия', 'петербургский', 'всемирный', 'санктпетербург', 'й']
# 🟩 Кластер 17 (36 событий)
#   - В Бейруте состоялся 14-й саммит Лиги арабских государств.
#   - Саммит глав СНГ в Казани.
#   - в Санкт-Петербурге состоялся саммит глав стран «Большой восьмёрки».
#   - Лондонский саммит G-20
#   - юбилейный саммит НАТО в Страсбурге, Келе и Баден-Бадене.
#   - саммит G8 в Л’Акуиле, Италия.
#   - саммит G20.
#   - саммит НАТО в Лиссабоне (Португалия).
#   - В Астане открылся юбилейный саммит ШОС, приуроченный к 10-летию Организации.
#   - в Душанбе (Таджикистан) прошёл саммит глав государств СНГ.
#   🗝️ Ключевые слова: ['саммит', 'g', 'государств', 'глав', 'состоялся', 'брикс', 'й', 'снг', 'нато', 'атэс']
# 🟩 Кластер 18 (22 событий)
#   - Президент России Владимир Путин подписал указ № 849 «О полномочном представителе Президента Российской Федерации в федеральном округе», согласно которому в России были созданы федеральные округа;
#   - президент Кыргызстана А. Акаев подписал закон о придании русскому языку официального статуса.
#   - Владимир Путин подписал Земельный кодекс.
#   - президент США Джордж Буш подписал указ о создании на территории гор Юкка в штате Невада могильника для радиоактивных отходов.
#   - Президент России Владимир Путин подписал закон «О ратификации Киотского протокола к Рамочной конвенции ООН об изменении климата». Киотский протокол вступил в силу 16 февраля 2005 года.
#   - Президент РФ Владимир Путин и федеральный канцлер ФРГ Ангела Меркель открыли в Дрездене памятник Фёдору Михайловичу Достоевскому работы народного художника России Александра Рукавишникова.
#   - президент Нигера Мамаду Танджа подписал указ о роспуске Национального собрания.
#   - Президент США Барак Обама подписал «Закон о доступном здравоохранении для Америки».
#   - Президент США Барак Обама подписал Закон о финансовой реформе.
#   - Президент РФ Дмитрий Медведев подписал федеральный закон «О полиции».
#   🗝️ Ключевые слова: ['президент', 'подписал', 'закон', 'россии', 'владимир', 'путин', 'указ', 'сша', 'казахстана', 'года']
# 🟩 Кластер 19 (28 событий)
#   - В Стокгольме (Швеция) состоялся 45-й Конкурс Песни Евровидение 2000.
#   - в Юрмале (Латвия) состоялся 1-й Международный конкурс молодых исполнителей популярной музыки «Новая волна».
#   - В Риге (Латвия) прошёл 48-й конкурс Евровидение.
#   - в Харькове (Украина) открылся 17-й Международный музыкальный фестиваль «Харьковские ассамблеи»—2010.
#   - 9-й международный фестиваль духовной музыки «Серебряные колокола» (Даугавпилс, Латвия).
#   - 10-й конкурс молодых исполнителей популярной музыки «Новая волна» (Юрмала, Латвия).
#   - 55-й Лондонский кинофестиваль.
#   - 65-й Каннский кинофестиваль.
#   - 34-й Московский международный кинофестиваль.
#   - 11-й международный конкурс молодых исполнителей популярной музыки «Новая волна» (Юрмала, Латвия).
#   🗝️ Ключевые слова: ['й', 'кинофестиваль', 'международный', 'конкурс', 'евровидение', 'латвия', 'музыки', 'московский', 'молодых', 'исполнителей']
# 🟩 Кластер 20 (18 событий)
#   - Проведение в трёх субъектах России повторных выборов глав регионов. Губернатором Московской области избран генерал Борис Громов («Отечество»)(48 %); губернатором Тверской области переизбран Владимир Платов («Единство»)(46,5 %); губернатором Новосибирской области избран мэр Новосибирска Виктор Толоконский (44,3 %);
#   - Ангиди Четтьяр занял пост и. о. президента Маврикия (до 18 февраля 2002 года).
#   - Ариранга Пиллай занял пост и. о. президента Маврикия (до 25 февраля 2002 года).
#   - Пандели Майко назначен председателем Совета министров Албании (до 31 июля 2002 года).
#   - Жак Юг Силла назначен на пост премьер-министра Мадагаскара (до 20 января 2007 года).
#   - Ивон Нептун назначен на пост премьер-министра Гаити (до 12 марта 2004 года).
#   🗝️ Ключевые слова: ['года', 'пост', 'премьерминистра', 'занял', 'назначен', 'председателя', 'боснии', 'марта', 'мая', 'апреля']
# 🟩 Кластер 22 (66 событий)
#   - назначение Ивицы Рачана новым премьер-министром Хорватии.
#   - Андраник Маргарян стал премьер-министром Армении.
#   - Али Бенфлис назначен премьер-министром Алжира.
#   - премьер-министром Таиланда стал Таксин Чиннават.
#   - Премьер-министром Польши стал Лешек Миллер.
#   - Андерс Фог Расмуссен избран премьер-министром Дании.
#   - Юхан Партс стал премьер-министром Эстонии.
#   - Ильхам Алиев назначен премьер-министром Азербайджана.
#   - Махатхир Мохамад ушёл в отставку с поста премьер-министра Малайзии. Он возглавлял страну более 22 лет. Абдулла Ахмад Бадави стал новым премьер-министром.
#   - Артур Расизаде назначен премьер-министром Азербайджана.
#   🗝️ Ключевые слова: ['премьерминистром', 'стал', 'новым', 'лидер', 'назначен', 'партии', 'армении', 'премьерминистра', 'отставку', 'греции']
# 🟩 Кластер 23 (55 событий)
#   - премьер-министр Израиля Эхуд Барак подал в отставку.
#   - Премьер-министр Японии Ёсиро Мори подал в отставку. На посту премьера его сменил Дзюнъитиро Коидзуми .
#   - президент Боливии Уго Бансер Суарес ушёл в отставку в связи с проблемами со здоровьем. Преемником стал вице-президент Хорхе Кирога.
#   - после несколько дней беспорядков и массовых протестов аргентинский президент Фернандо де ла Руа ушёл в отставку.
#   - Итальянский премьер-министр Сильвио Берлускони вручил прошение о своей отставке итальянскому президенту Карло Чампи.
#   - премьер-министр Италии Романо Проди подал в отставку.
#   - президент Египта Хосни Мубарак покинул свой пост.
#   - бывший президент Египта Хосни Мубарак заключён под домашний арест.
#   - премьер-министр Греции Георгиос Папандреу подал в отставку.
#   - премьер-министр Италии Сильвио Берлускони ушёл в отставку.
#   🗝️ Ключевые слова: ['отставку', 'президента', 'президент', 'обязанности', 'подал', 'премьерминистр', 'ушл', 'страны', 'стал', 'исполняющим']
# 🟩 Кластер 24 (23 событий)
#   - в Лозанне состоялся чемпионат Европы по фигурному катанию. Победу в общекомандном зачёте одержала сборная России.
#   - в Нагано состоялся чемпионат мира по фигурному катанию. Победу в общекомандном зачёте одержала сборная России.
#   - в Анталье (Турция) состоялся 81-й чемпионат Европы по тяжёлой атлетике. Победу в общекомандном зачёте одержала Болгария.
#   - в финском Лахти состоялся 48-й чемпионат мира по стрельбе. Победу в общекомандном зачёте одержала сборная России.
#   - в Перми состоялся 34-й чемпионат Европы по боксу. Победу в общекомандном зачёте одержала Россия.
#   - в Мюнхене состоялся 18-й чемпионат Европы по лёгкой атлетике. Победу в общекомандном зачёте одержала сборная России.
#   - чемпионат мира по горнолыжному спорту среди юниоров (Роккарасо, Италия).
#   - чемпионат мира по биатлону (Рупольдинг, Германия).
#   - чемпионат мира по кёрлингу (Летбридж, Канада).
#   - чемпионат мира по фигурному катанию (Ницца, Франция).
#   - чемпионат мира по современному пятиборью (Рим, Италия).
#   🗝️ Ключевые слова: ['чемпионат', 'мира', 'европы', 'гимнастике', 'хоккею', 'атлетике', 'фигурному', 'катанию', 'лгкой', 'германия']
# 🟩 Кластер 32 (12 событий)
#   - Чемпионат Европы по биатлону 2005 (Новосибирск, Россия).
#   - чемпионат мира по фигурному катанию (Москва, Россия).
#   - чемпионат мира по конькобежному спорту (Москва, Россия).
#   - чемпионат мира по летнему биатлону (Уфа, Россия).
#   - молодёжный чемпионат мира по хоккею c шайбой (Уфа, Россия).
#   - чемпионат мира по самбо (Санкт-Петербург, Россия).
#   - чемпионат мира по фехтованию (Казань, Россия).
#   - чемпионат мира по гребле на байдарках и каноэ (Москва, Россия).
#   - Чемпионат мира по летнему биатлону (Тюмень, Россия).
#   - чемпионат мира по дзюдо в Челябинске (Россия).
#   🗝️ Ключевые слова: ['чемпионат', 'россия', 'мира', 'москва', 'биатлону', 'конькобежному', 'спорту', 'летнему', 'уфа', 'европы']
# 🟩 Кластер 33 (15 событий)
#   - Президентом Турции избран Ахмет Сезер;
#   - президентом Венгрии избран Ференц Мадл.
#   - Президентом Литвы избран Роландас Паксас.
#   - Тассос Пападопулос избран президентом Кипра.
#   - Поль Кагаме избран президентом Руанды.
#   - Президентом Литвы избрана Даля Грибаускайте.
#   - Янош Адер избран новым президентом Венгрии.
#   - президентом Сомали избран Хасан Шейх Махмуд.
#   - новым президентом Эфиопии избран Мулату Тешоме.
#   - президентом Словении переизбран Борут Пахор.
#   🗝️ Ключевые слова: ['президентом', 'избран', 'венгрии', 'избрана', 'литвы', 'новым', 'турции', 'ахмет', 'сезер', 'ференц']
# 🟩 Кластер 34 (21 событий)
#   - Деноминация белорусского рубля;
#   - Объявление компаний «AOL» и «Time Warner» о планах слияния с компанией «AOL Time Warner».
#   - обнаружен человеческий ген долголетия.
#   - авиакомпания Sabena признана банкротом.
#   - Вошла в оборот купюра номиналом в 20 000 белорусских рублей.
#   - Австралийскими учёными обнаружен ген эпилепсии.
#   - На телеканале Fox была показана последняя серия культового американского телесериала «Секретные материалы».
#   - вошла в оборот купюра номиналом 50 000 белорусских рублей.
#   - вошла в оборот купюра номиналом в 100 000 белорусских рублей.
#   - Государства—участники Женевских конвенций приняли Третий дополнительный протокол, устанавливающий дополнительную эмблему — красный кристалл. Дополнительным протоколом III была принята эмблема, лишённая какого-либо религиозного, культурного или политического значения; которая обладает таким же правовым статусом, как и красный крест и красный полумесяц, и может быть использована на тех же условиях.
#   🗝️ Ключевые слова: ['вошла', 'купюра', 'номиналом', 'рублей', 'деноминация', 'оборот', 'белорусских', 'красный', 'белорусского', 'рубля']
# 🟩 Кластер 35 (21 событий)
#   - выход «Microsoft Windows 2000».
#   - Корпорация Microsoft выпустила операционную систему Windows Millennium Edition;
#   - Компания «Apple Computers» выпустила операционную систему «Mac OS X» (10 версию операционной системы «Mac OS»).
#   - Компания «Microsoft» выпустила операционную систему «Windows XP».
#   - прекращение поддержки Windows 1.0x.
#   - выход Windows Server 2003.
#   - Майкрософт прекратила поддержку ОС Windows 98 и Windows Me.
#   - Microsoft официально завершила разработку ОС Windows Vista и передала её своим «Золотым партнёрам».
#   - Выход Windows Server 2008.
#   - корпорация Microsoft прекратила расширенную поддержку ОС Windows XP.
#   🗝️ Ключевые слова: ['windows', 'microsoft', 'server', 'операционную', 'систему', 'компания', 'выход', 'выпустила', 'поддержки', 'ос']
# 🟩 Кластер 36 (40 событий)
#   - 97-й старт «STS-99» по программе «Спейс шаттл». 14-й полёт шаттла «Индевор». Экипаж — Кевин Крегель, Доминик Гори, Герхард Тиле (Германия), Джанет Каванди, Дженис Восс, Мамору Мори (Япония). Основная задача полёта — радиолокационная топографическая.
#   - 98-й старт («STS-101») по программе Спейс Шаттл. 21-й полёт шаттла Атлантис. Экипаж — Джеймс Халселл, Скотт Хоровитц, Сьюзан Хелмс, Юрий Усачёв (Россия), Джеймс Восс, Мэри Уэбер, Джеффри Уильямс.
#   - 99-й старт по программе Спейс Шаттл (STS-106). 22-й полёт шаттла Атлантис. Экипаж — Терренс Уилкатт, Скотт Олтман, Дэниел Бёрбэнк, Эдвард Лу, Ричард Мастраккио, Юрий Маленченко (Россия), Борис Моруков (Россия);
#   - 100-й старт по программе Спейс Шаттл (STS-92). 28-й полёт шаттла Дискавери. Экипаж — Брайан Даффи, Памела Мелрой, Лерой Чиао, Уильям МакАртур, Питер Уайсофф, Майкл Лопес-Алегриа, Коити Ваката.
#   - 101-й старт (STS-97) по программе Спейс Шаттл. 15-й полёт шаттла Индевор. Экипаж — Брент Джетт, Майкл Блумфилд, Джозеф Таннер, Марк Гарно (Канада), Карлос Норьега.
#   - 102-й старт (STS-98) по программе Спейс Шаттл. 23-й полёт шаттла Атлантис. Экипаж — Кеннет Кокрелл, Марк Ролански, Роберт Курбим, Марша Айвинс, Томас Джоунс. Доставка модуля «Дестини» для МКС.
#   - 103-й старт (STS-102) по программе Спейс Шаттл. 29-й полёт шаттла Дискавери. Экипаж — Джеймс Уэзерби, Джеймс Келли, Эндрю Томас, Пол Ричардс, Джеймс Восс, Сьюзан Хэлмс, Юрий Усачёв(Россия).
#   - 104-й старт (STS-100) по программе Спейс Шаттл. 16-й полёт шаттла Индевор. Экипаж — Кент Роминджер, Джеффри Эшби, Крис Хэдфилд (Канада), Джон Филипс, Скот Паразински, Умберто Гуидони (Италия), Юрий Лончаков (Россия).
#   - 105-й старт (STS-104) по программе Спейс Шаттл. 24-й полёт шаттла Атлантис. Экипаж — Стивен Линдсей, Чарлз Хобо, Майкл Гернхардт, Джанет Каванди, Джеймс Рейли.
#   - 106-й старт (STS-105) по программе Спейс Шаттл. 30-й полёт шаттла Дискавери. Экипаж: Скотт Хоровиц, Фредерик Стеркоу, Патрик Форрестер, Даниэль Барри, Фрэнк Калбертсон, Владимир Дежуров (Россия), Михаил Тюрин (Россия).
#   - старт космического корабля Союз ТМ-33. Экипаж старта — В. М. Афанасьев, К. М. Козеев и К. Эньере (Франция).
#   - Приземление корабля Союз ТМ-32. Экипаж посадки — В. М. Афанасьев, К. М. Козеев и К. Эньере (Франция).
#   - Приземление корабля Союз ТМ-33. Экипаж посадки — Ю. П. Гидзенко, Р. Виттори (Италия) и М. Шаттлуорт (ЮАР).
#   - Старт космического корабля Союз ТМА-1. Экипаж старта — Ю. В. Лончаков, С. В. Залётин и Франк Де Винне (Бельгия).
#   - приземление корабля Союз ТМ-34. Экипаж посадки — Ю. В. Лончаков, С. В. Залётин и Франк Де Винне (Бельгия).
#   🗝️ Ключевые слова: ['союз', 'экипаж', 'корабля', 'сша', 'космического', 'тма', 'посадки', 'космический', 'приземление', 'старта']
# 🟩 Кластер 40 (43 событий)
#   - с космодрома Байконур осуществлён запуск ракеты-носителя Союз-У с транспортным грузовом космическим кораблём Прогресс М1-8. Экспедиция по снабжению МКС (сведён с орбиты 25 июня).
#   - С космодрома Байконур осуществлён запуск ракеты-носителя Союз-У с транспортным грузовым космическим кораблём Прогресс М-46. Экспедиция по снабжению МКС (сведён с орбиты 14 октября).
#   - С космодрома Байконур осуществлён запуск ракеты-носителя Союз-ФГ с транспортным грузовом космическим кораблём Прогресс М1-9. Экспедиция по снабжению МКС (сведён с орбиты 1 февраля 2003 года).
#   - с космодрома Мыс Канаверал с помощью ракеты-носителя Дельта-2 7320-10 запущена орбитальная обсерватория Swift.
#   - зонд «Гюйгенс» отделился от космического аппарата «Кассини» и отправился к Титану.
#   - с космодрома Байконур успешно стартовала ракета-носитель «Союз-ФГ» с межпланетной станцией «Венера Экспресс».
#   - с космодрома Канаверал с помощью ракеты-носителя Атлас V запущена американская АМС New Horizons, предназначенная для исследования Плутона.
#   - из Космического центра Танэгасима с помощью ракеты-носителя H-IIA запущен спутник ДЗЗ ALOS.
#   - с индийского космодрома Шрихарикота с помощью ракеты-носителя PSLV-C8 запущен итальянский астрономический спутник AGILE.
#   - с космодрома Байконур с помощью ракеты-носителя Днепр запущен немецкий спутник TerraSAR-X.
#   🗝️ Ключевые слова: ['космодрома', 'байконур', 'ракетыносителя', 'ракетаноситель', 'помощью', 'запущена', 'стартовала', 'запуск', 'протонм', 'спутником']
# 🟩 Кластер 41 (652 событий)
#   - крушение украинского сухогруза типа «река-море» «Тикси» (порт приписки Николаев, под флагом Камбоджи) с грузом зерна на борту на траверсе мыса Джубга около Туапсе. Во время шторма судно разломилось пополам, экипажу удалось высадиться на плоты. Один человек погиб.
#   - Крушение авиалайнера «Saab 340» авиакомпании «Crossair» у деревни Нассенвиль в Нидерхасли (Швейцария). Погибли все находившиеся на его борту 10 человек — 7 пассажиров и 3 члена экипажа;
#   - Катастрофа A310 под Абиджаном, погибло 169 человек;
#   - падение авиалайнера «McDonnell Douglas MD-83» авиакомпании «Alaska Airlines» рейса AS 261 по маршруту Пуэрто-Вальярта—Сан-Франциско—Сиэтл при подлёте к Сан-Франциско в 4,5 километрах от побережья острова Анакапа (Калифорния). Погибли все находившиеся на его борту 88 человек — 83 пассажира и 5 членов экипажа.
#   - Взрыв жилого дома по улице Артёмовской в Хабаровске. Погибло 13 человек
#   - крушение грузового самолёта «Douglas DC-8-71F» компании «Emery Worldwide» вблизи Ранчо-Кордова (Калифорния, США). Погибло 3 человека.
#   - возникновение сильных наводнений, вызванных проливными дождями, в Мозамбике. Погибло более 700 человек.
#   - в результате столкновения двух поездов токийского метро на линии «Хибия» близ станции «Нака-Мэгуро» погибли 5 и ранены 63 человека.
#   - в результате авиационной катастрофы близ Шереметьево погибли журналист Артём Боровик и мультимиллионер Зия Бажаев.
#   - в округе Канунгу (Уганда) члены религиозной секты «Восстановление десяти господних заповедей» совершили акцию массового самосожжения: погибло около 600 человек.
#   🗝️ Ключевые слова: ['человек', 'погибли', 'результате', 'человека', 'погибло', 'получили', 'ранения', 'ранены', 'около', 'землетрясение']
# 🟩 Кластер 42 (50 событий)
#   - Вторая чеченская война: большие потери Сергиево-Посадского ОМОНа (22 убито и более 30 ранено) в результате «дружественного огня».
#   - Вторая чеченская война: Село Комсомольское освобождено от боевиков федеральными войсками.
#   - Вторая чеченская война: гибель подразделения пермского ОМОНа у селения Джани-Ведено. Погибло более 40 человек.
#   - Вторая чеченская война: в селе Алхан-Юрт (Чечня) двое террористов-смертников взорвали гружённый взрывчаткой грузовик вблизи здания милиции. Одной из смертниц была родственница Мовсара Бараева, позднее захватившего в 2002 здание театрального центра на Дубровке (Москва). Погибли двое милиционеров, пятеро были ранены
#   - Вторая чеченская война: в результате серии терактов с использованием заминированных грузовиков погибло более 30 милиционеров и военнослужащих федеральных сил;
#   - Вторая чеченская война: осуществлена попытка подрыва здания комендатуры Ленинского района (Грозный, Чечня);
#   - Вторая чеченская война: Нападение боевиков на Ханкалу.
#   - Вторая чеченская война: в Грозном сбит вертолёт с военной комиссией Генерального Штаба, погибли 13 человек.
#   - Вторая чеченская война: нападение боевиков на Гудермес: нападение отбито, в результате применения ракетного комплекса Точка-У уничтожена группа более чем в 100 человек.
#   - Вторая чеченская война: женщина-смертница (вдова погибшего боевика) подорвала себя на центральной площади Урус-Мартана (Чечня), когда там находился комендант района генерал-майор Гейдар Гаджиев. Гаджиев погиб, трое охранников ранены.
#   🗝️ Ключевые слова: ['война', 'вторая', 'чеченская', 'вертолт', 'человек', 'погибли', 'получили', 'ранения', 'афганистане', 'районе']
# 🟩 Кластер 43 (28 событий)
#   - Первый тур президентских выборов в Финляндии;
#   - В Азербайджане прошёл первый тур парламентских выборов.
#   - в Словении прошёл первый тур президентских выборов.
#   - В Молдавии состоялся первый тур всеобщих местных выборов.
#   - в Хорватии прошёл первый тур президентских выборов.
#   - второй тур президентских выборов в Польше, победа Леха Качиньского.
#   - первый тур президентских выборов в Республике Македонии.
#   - второй тур президентских выборов в Республике Македонии.
#   - первый тур Президентских выборов на Украине.
#   - В Перу прошёл второй тур президентских выборов. Победил левый кандидат Ольянта Умала.
#   🗝️ Ключевые слова: ['тур', 'выборов', 'президентских', 'первый', 'второй', 'парламентских', 'прошл', 'состоялся', 'республике', 'македонии']
#   - Выборы президента Нагорного Карабаха. Победу одержал действующий президент Бако Саакян.
#   - выборы президента Венесуэлы. Победу одержал Уго Чавес.
#   - Выборы президента Эквадора. Победу одержал действующий президент Рафаэль Корреа.
#   - президентские выборы в Черногории. По предварительным результатам, победу одержал действующий президент Филип Вуянович.
#   🗝️ Ключевые слова: ['выборы', 'победу', 'одержал', 'президентские', 'действующий', 'президент', 'президента', 'предварительным', 'данным', 'парламентские']
# 🟩 Кластер 47 (38 событий)
#   - Второй тур президентских выборов в Болгарии. Победу одержал Росен Плевнелиев.
#   - второй тур выборов президента Финляндии. Победу одержал Саули Ниинисте.
#   - Второй тур выборов президента Сербии. Победу одержал Томислав Николич.
#   - второй тур выборов президента Чехии. Победу одержал Милош Земан.
#   - Второй тур выборов президента Республики Кипр. Победу одержал Никос Анастасиадис.
#   - Второй тур президентских выборов на Мальдивах. Победу одержал Абдулла Ямин.
#   - второй тур президентских выборов и парламентские выборы на Мадагаскаре. Победу одержал Эри Раджаонаримампианина.
#   - второй тур выборов президента Словакии. Победу одержал самовыдвиженец Андрей Киска.
#   - В Коста-Рике состоялся второй тур президентских выборов, победу одержал Луис Гильермо Солис.
#   - второй тур президентских выборов в Гвинее-Бисау. Победу одержал Жозе Мариу Ваш.
#   🗝️ Ключевые слова: ['второй', 'тур', 'победу', 'выборов', 'одержал', 'президентских', 'президента', 'выборы', 'одержала', 'действующий']
# 🟩 Кластер 48 (21 событий)
#   - Президентские выборы в Финляндии.
#   - Президентские выборы на Мальдивах.
#   - президентские выборы на Мадагаскаре.
#   - Повторные президентские выборы на Мальдивах.
#   - Президентские и парламентские выборы в Чили.
#   - президентские выборы в Ливане.
#   - Парламентские и президентские выборы в Бразилии.
#   - Парламентские и президентские выборы в Уругвае.
#   - Президентские выборы в Австрии.
#   - Президентские выборы в Экваториальной Гвинее.
#   🗝️ Ключевые слова: ['президентские', 'выборы', 'парламентские', 'финляндии', 'мальдивах', 'мадагаскаре', 'повторные', 'чили', 'ливане', 'бразилии']
# 🟩 Кластер 49 (10 событий)
#   - досрочные парламентские выборы в Молдове.
#   - Досрочные парламентские выборы в Иордании.
#   - Досрочные парламентские выборы в Косове.
#   - досрочные парламентские выборы в Исландии.
#   - Досрочные парламентские выборы в Македонии.
#   - Досрочные парламентские выборы в Австрии.
#   - досрочные парламентские выборы в Словении.
#   - досрочные парламентские выборы в Австрии.???
#   - досрочные парламентские выборы в Азербайджане.
#   - Внеочередные парламентские выборы в Португалии.
#   🗝️ Ключевые слова: ['парламентские', 'выборы', 'досрочные', 'австрии', 'молдове', 'иордании', 'косове', 'исландии', 'македонии', 'словении']
# 🟩 Кластер 50 (49 событий)
#   - парламентские выборы в Науру.
#   - Парламентские выборы на Аландских островах
#   - парламентские выборы в Белоруссии.
#   - парламентские выборы в Молдове.
#   - Парламентские выборы в Литве.
#   - парламентские выборы на Кубе.
#   - Парламентские выборы на Мальте.
#   - парламентские выборы в Исландии.
#   - парламентские выборы в Науру.
#   - Парламентские выборы в Свазиленде.
#   🗝️ Ключевые слова: ['парламентские', 'выборы', 'островах', 'науру', 'белоруссии', 'литве', 'камеруне', 'мальдивах', 'узбекистане', 'венесуэле']

# %%
import umap
import matplotlib.pyplot as plt

umap_embeddings = umap.UMAP(n_neighbors=15, min_dist=0.1).fit_transform(X_norm)

plt.figure(figsize=(10, 7))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1],
            c=df["cluster"], cmap="Spectral", s=50)
plt.title("Кластеризация событий (word2vec + HDBSCAN)")
plt.show()

# %%
from sklearn.metrics import silhouette_score

mask = labels != -1
score = silhouette_score(X[mask], labels[mask])
score
# Out:
# 0.3625284865862363

# %%
import itertools
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import hdbscan
from tqdm import tqdm

# ==== 3. Пространство гиперпараметров ====
param_grid = {
    "vector_size": [100, 200, 300],
    "window": [3, 5, 8, 10],
    "min_count": [1, 2, 5],
    "sg": [0, 1],  # 0 — CBOW, 1 — Skip-gram
}

param_combinations = list(itertools.product(*param_grid.values()))
param_names = list(param_grid.keys())

results = []

# ==== 4. Перебор параметров ====
for params in tqdm(param_combinations, desc="Grid Search Word2Vec"):
    param_dict = dict(zip(param_names, params))

    # 4.1 Обучаем Word2Vec
    model = Word2Vec(
        sentences=corpus,
        **param_dict,
        workers=4,
        epochs=20,
        seed=42
    )

    # 4.2 Векторизация событий
    X = np.vstack([vectorize(tokens, model) for tokens in corpus])
    X_norm = normalize(X, norm='l2')
    # 4.3 Кластеризация (можно выбрать KMeans или HDBSCAN)
    # HDBSCAN (автоматически подбирает число кластеров)
    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=10,
        min_samples=3,
        metric='cosine',
        algorithm='generic',
    )
    labels = clusterer.fit_predict(X_norm)

    # Игнорируем шумовые точки (-1)
    mask = labels != -1
    if len(set(labels[mask])) < 2:
        continue

    # ==== 4.4 Метрики ====
    sil = silhouette_score(X_norm[mask], labels[mask])
    db = davies_bouldin_score(X_norm[mask], labels[mask])
    ch = calinski_harabasz_score(X_norm[mask], labels[mask])

    results.append({
        **param_dict,
        "silhouette": sil,
        "davies_bouldin": db,
        "calinski_harabasz": ch,
        "clusters": len(set(labels[mask]))
    })

# ==== 5. Анализ результатов ====
results_df = pd.DataFrame(results)
results_df = results_df.sort_values("silhouette", ascending=False)

print("\nЛучшие параметры по silhouette:")
print(results_df.head(10))

# Можно также вывести среднюю оценку с весами
results_df["score_combined"] = (
        results_df["silhouette"] * 2
        - results_df["davies_bouldin"] * 0.5
        + np.log1p(results_df["calinski_harabasz"]) * 0.1
)

print("\nТоп по комбинированному скору:")
results_df.sort_values("score_combined", ascending=False).head(10)
# Out:
# Grid Search Word2Vec:  12%|█▎        | 9/72 [00:27<03:18,  3.15s/it]

# %%
# === 1. Обучаем Word2Vec с выбранными параметрами ===
best_params = {
    "vector_size": 200,
    "window": 8,
    "min_count": 1,
    "sg": 0,  # Skip-gram
    "workers": 4,
    "epochs": 20,
    "seed": 42
}

model = Word2Vec(sentences=corpus, **best_params)

X = np.vstack([vectorize(tokens, model) for tokens in corpus])
X_norm = normalize(X, norm='l2')

# === 3. Кластеризация (можно поменять min_cluster_size) ===
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=10,
    min_samples=3,
    metric='cosine',
    algorithm='generic',

)
labels = clusterer.fit_predict(X_norm)
df["tokens"] = corpus
df["cluster"] = labels

# === 4. Метрики качества ===
mask = labels != -1
if len(set(labels[mask])) > 1:
    sil = silhouette_score(X_norm[mask], labels[mask])
    db = davies_bouldin_score(X_norm[mask], labels[mask])
    ch = calinski_harabasz_score(X_norm[mask], labels[mask])
    print(f"Silhouette: {sil:.3f}, Davies–Bouldin: {db:.3f}, Calinski–Harabasz: {ch:.1f}")
else:
    print("Недостаточно кластеров для расчёта метрик")

# === 5. Сводка по кластерам ===
print("\n📊 Кластеры:")
print(df["cluster"].value_counts().sort_index())

# === 6. Вывод топ-слов по каждому кластеру ===
for cluster_id in sorted(df["cluster"].unique()):
    if cluster_id == -1:
        continue
    subset = df[df["cluster"] == cluster_id]
    tokens = [t for tokens in subset["tokens"] for t in tokens if t in model.wv]
    top_words = [w for w, _ in Counter(tokens).most_common(30)]
    print(f"\nКластер {cluster_id}: {top_words}")
# Out:
# Silhouette: 0.469, Davies–Bouldin: 0.743, Calinski–Harabasz: 2354.8
#
# 📊 Кластеры:
# cluster
# -1     3520
#  0       17
#  1       13
#  2       12
#  3       14
#        ...
#  57     169
#  58      11
#  59      12
#  60     432
#  61      41
# Name: count, Length: 63, dtype: int64
#
# Кластер 0: ['война', 'вторая', 'чеченская', 'боевиков', 'нападение', 'го', 'полка', 'грозный', 'внутренних', 'мвд', 'село', 'комсомольское', 'освобождено', 'федеральными', 'войсками', 'послке', 'новогрозненский', 'сотрудниками', 'фсб', 'захвачен', 'доставлен', 'москву', 'террорист', 'салман', 'радуев', 'впоследствии', 'осужднный', 'пожизненному', 'лишению', 'свободы']
#
# Кластер 1: ['единый', 'день', 'голосования', 'россии', 'десятый', 'беларуси']
#
# Кластер 2: ['россии', 'форум', 'казахстана', 'россия', 'межрегионального', 'сотрудничества', 'казахстан', 'приграничных', 'регионов', 'i', 'омск', 'ii', 'челябинск', 'iii', 'уральск', 'iv', 'новосибирск', 'vii', 'устькаменогорск', 'viii', 'астрахань', 'официальное', 'вступление', 'вто', 'стала', 'м', 'членом', 'организации', 'x', 'екатеринбург']
#
# Кластер 3: ['й', 'шаттла', 'шаттл', 'полт', 'старт', 'программе', 'спейс', 'экипаж', 'продолжение', 'строительства', 'международной', 'космической', 'станции', 'sts', 'индевор', 'стивен', 'дискавери', 'майкл', 'ричард', 'япония', 'атлантис', 'патрик', 'джон', 'келли', 'грегори', 'роберт', 'марк', 'фредерик', 'стеркоу', 'аршамбо']
#
# Кластер 4: ['й', 'старт', 'программе', 'спейс', 'шаттл', 'sts', 'полт', 'шаттла', 'экипаж', 'дискавери', 'майкл', 'джеймс', 'марк', 'атлантис', 'томас', 'уильям', 'роберт', 'келли', 'стивен', 'памела', 'мелрой', 'брент', 'джетт', 'джозеф', 'таннер', 'канада', 'курбим', 'мкс', 'эндрю', 'линдсей']
#
# Кластер 5: ['стала', 'совета', 'европейского', 'союза', 'государствомпредседателем', 'первым', 'председателем', 'шумахер', 'стал', 'кратным', 'чемпионом', 'рекорд', 'человеком', 'обсе', 'михаэль', 'истории', 'гонок', 'формула', 'мира', 'побив', 'количеству', 'чемпионских', 'титулов', 'хуанамануэля', 'фанхио', 'державшийся', 'года', 'непревзойднным', 'неповторнным', 'вторым']
#
# Кластер 6: ['евровидение', 'песни', 'й', 'победу', 'конкурс', 'одержала', 'проведение', 'го', 'конкурса', 'состоялся', 'швеция', 'одержал', 'представительница', 'фдорова', 'украина', 'песней', 'детское', 'копенгагене', 'международном', 'музыкальном', 'конкурсе', 'дуэт', 'эстонии', 'танель', 'падар', 'дэйв', 'бентон', 'таллине', 'исполнительница', 'marie']
#
# Кластер 7: ['игры', 'олимпийские', 'летние', 'зимние', 'юношеские', 'паралимпийские', 'всемирные', 'кочевников', 'азиатские', 'пекине', 'первые', 'китай', 'великобритания', 'ii', 'кыргызстан', 'баку', 'азербайджан', 'риодежанейро', 'бразилия', 'пхнчхан', 'республика', 'корея', 'содружества', 'германии', 'афинах', 'греция', 'турине', 'италия', 'начались', 'хх']
#
# Кластер 8: ['сборная', 'победу', 'одержала', 'чемпионат', 'мира', 'й', 'состоялся', 'россии', 'европы', 'зачте', 'второе', 'место', 'заняла', 'третье', 'общекомандном', 'хоккею', 'среди', 'шайбой', 'россия', 'женщин', 'футболу', 'швеции', 'атлетике', 'мужчин', 'турция', 'тяжлой', 'германии', 'баскетболу', 'франции', 'кубок']
#
# Кластер 9: ['й', 'чемпионат', 'мира', 'хоккею', 'казахстан', 'россия', 'мячом', 'водным', 'видам', 'спорта', 'боксу', 'астана', 'шайбой', 'германия', 'алмаата', 'бобслею', 'скелетону', 'европы', 'художественной', 'гимнастике', 'нижний', 'новгород', 'барселона', 'испания', 'алматы', 'конькобежному', 'спорту', 'спринтерском', 'многоборье', 'хабаровск']
#
# Кластер 10: ['чемпионат', 'мира', 'европы', 'атлетике', 'фигурному', 'катанию', 'гимнастике', 'лгкой', 'германия', 'борьбе', 'хоккею', 'художественной', 'шайбой', 'видам', 'спорта', 'япония', 'венгрия', 'кнр', 'футболу', 'биатлону', 'канада', 'фехтованию', 'современному', 'пятиборью', 'италия', 'плаванию', 'финляндия', 'среди', 'будапешт', 'гребле']
#
# Кластер 11: ['чемпионат', 'россия', 'мира', 'биатлону', 'москва', 'европы', 'конькобежному', 'спорту', 'летнему', 'уфа', 'хоккею', 'новосибирск', 'фигурному', 'катанию', 'молоджный', 'c', 'шайбой', 'самбо', 'санктпетербург', 'фехтованию', 'казань', 'гребле', 'байдарках', 'каноэ', 'тюмень', 'дзюдо', 'челябинске', 'отдельных', 'дистанциях', 'коломна']
#
# Кластер 12: ['референдум', 'избирателей', 'состоялся', 'ес', 'конституции', 'вопросу', 'высказались', 'вступлении', 'независимости', 'прошл', 'срока', 'большинство', 'голосовании', 'приняло', 'участие', 'процентов', 'зарегистрированных', 'поддержку', 'вступления', 'евросоюз', 'словакии', 'поддержало', 'изменению', 'кыргызстана', 'франции', 'конституционный', 'сокращении', 'президентского', 'лет', 'относительно']
#
# Кластер 13: ['саммит', 'g', 'нато', 'атэс', 'германия', 'япония', 'лондонский', 'юбилейный', 'страсбурге', 'келе', 'баденбадене', 'лакуиле', 'италия', 'лиссабоне', 'португалия', 'ес', 'лоскабос', 'мексика', 'владивостоке', 'лохэрн', 'великобритания', 'пекин', 'китай', 'брисбене', 'австралия', 'замке', 'эльмау', 'бавария', 'анталье', 'турция']
#
# Кластер 14: ['й', 'международный', 'саммит', 'музыки', 'латвия', 'кинофестиваль', 'фильм', 'золотой', 'конкурс', 'молодых', 'исполнителей', 'популярной', 'новая', 'волна', 'юрмала', 'состоялся', 'награду', 'лучший', 'получила', 'драма', 'фестиваль', 'группы', 'двадцати', 'франция', 'остановлен', 'реактор', 'чернобыльской', 'аэс', 'электростанция', 'окончательно']
#
# Кластер 15: ['й', 'кинофестиваль', 'международный', 'московский', 'венецианский', 'каннский', 'берлинский', 'лондонский', 'канны', 'франция']
#
# Кластер 16: ['стал', 'новым', 'ii', 'королм', 'аль', 'членом', 'брак', 'первым', 'генеральным', 'секретарм', 'король', 'бельгии', 'престола', 'дома', 'романовых', 'князь', 'романович', 'главой', 'брат', 'сауд', 'германии', 'королевы', 'тайвань', 'всемирной', 'торговой', 'организации', 'верховный', 'суд', 'массачусетса', 'посчитал']
#
# Кластер 17: ['россии', 'закон', 'государственная', 'дума', 'приняла', 'силу', 'принят', 'вступили', 'новые', 'правила', 'автомобилей', 'альтернативной', 'гражданской', 'службе', 'обороте', 'сельскохозяйственных', 'земель', 'противодействии', 'экстремистской', 'деятельности', 'парламенты', 'украины', 'ратифицировали', 'соглашение', 'поводу', 'продления', 'срока', 'пребывания', 'черноморского', 'флота']
#
# Кластер 18: ['россии', 'рф', 'начали', 'граждан', 'территории', 'украину', 'опг', 'государственный', 'флаг', 'территорию', 'лидерами', 'китая', 'казахстана', 'организация', 'решение', 'введн', 'вещание', 'fox', 'kids', 'округ', 'деятельность', 'игорных', 'государственная', 'дума', 'ратифицировала', 'договор', 'режим', 'беларуси', 'флота', 'сша']
#
# Кластер 19: ['дипломатические', 'отношения', 'установили', 'разорвала', 'узбекистан', 'отношение', 'бутан', 'украина', 'установлены', 'арменией', 'армения', 'восточный', 'тимор', 'кндр', 'саудовская', 'аравия', 'ираном', 'мьянма', 'костарика', 'парагвай', 'бруней', 'буркинафасо', 'ангола', 'тунис', 'вьетнам', 'австралия', 'гондурас', 'сингапур', 'хорватия', 'камерун']
#
# Кластер 20: ['партия', 'победу', 'одержала', 'парламентских', 'выборов', 'проведение', 'туре', 'выборах', 'досрочных', 'мест', 'либеральная', 'втором', 'правящая', 'палате', 'первом', 'президентских', 'перу', 'получила', 'большинство', 'второе', 'место', 'всеобщих', 'эфиопии', 'коалиция', 'рдфэн', 'завоевавшая', 'народных', 'представителей', 'азербайджане', 'новый']
#
# Кластер 21: ['выборы', 'президента', 'президент', 'действующий', 'избран', 'президентские', 'переизбран', 'президентом', 'срок', 'победил', 'страны', 'латвии', 'всеобщие', 'состоялись', 'голосов', 'казахстане', 'нурсултан', 'назарбаев', 'республики', 'молдовы', 'бывший', 'очередной', 'новый', 'сальвадоре', 'россии', 'северной', 'осетии', 'главой', 'региона', 'александр']
#
# Кластер 22: ['выборы', 'президентские', 'избран', 'президентом', 'парламент', 'парламентские', 'мохамед', 'всеобщие', 'страны', 'греции', 'абдуллахи', 'венесуэле', 'проведены', 'региональные', 'переизбран', 'уго', 'чавес', 'голосов', 'беларуси', 'парагвае', 'парагвая', 'орасио', 'картес', 'пакистане', 'мамнун', 'хусейн', 'гондурасе', 'предварительным', 'данным', 'хуан']
#
# Кластер 23: ['вступил', 'силу', 'закон', 'российской', 'федерации', 'россии', 'кодекс', 'новый', 'земельный', 'государственном', 'пенсионном', 'обеспечении', 'трудовой', 'лицензировании', 'отдельных', 'видов', 'деятельности', 'действие', 'уголовнопроцессуальный', 'упк', 'арбитражный', 'процессуальный', 'бельгии', 'эвтаназии', 'израиле', 'гражданском', 'браке', 'нерелигиозных', 'граждан', 'полиции']
#
# Кластер 24: ['победу', 'выборы', 'одержал', 'президентские', 'президента', 'действующий', 'президент', 'партии', 'кандидат', 'состоялись', 'парламентские', 'правящей', 'предварительным', 'внеочередные', 'александр', 'досрочные', 'выборах', 'представитель', 'данным', 'всеобщие', 'оппозиционной', 'черногории', 'южной', 'голосов', 'колумбии', 'индии', 'летний', 'абдул', 'социалдемократической', 'джордж']
#
# Кластер 25: ['выборы', 'второй', 'президента', 'президент', 'тур', 'действующий', 'срок', 'вышли', 'переизбран', 'выборов', 'президентские', 'лидер', 'мухаммед', 'бывший', 'премьерминистр', 'партии', 'польши', 'приднестровской', 'молдавской', 'республики', 'назначен', 'декабря', 'египта', 'движения', 'братьямусульмане', 'мурси', 'ахмед', 'шафик', 'словении', 'данило']
#
# Кластер 26: ['выборы', 'тур', 'второй', 'президентские', 'вышли', 'виктор', 'румынии', 'парламентские', 'иране', 'абхазии', 'прошли', 'украине', 'выборов', 'ющенко', 'янукович', 'кипре', 'никос', 'анастасиадис', 'ставрос', 'малас', 'сальвадоре', 'действующий', 'премьерминистр', 'понта', 'мэр', 'сибиу', 'клаус', 'йоханнис', 'масуд', 'пезешкиан']
#
# Кластер 27: ['вторая', 'чеченская', 'война', 'погибли', 'человек', 'сбит', 'вертолт', 'погибло', 'районе', 'результате', 'грозном', 'нападение', 'россии', 'человека', 'ранено', 'пзрк', 'вс', 'рф', 'мимт', 'ханкалы', 'гибель', 'подразделения', 'пермского', 'омона', 'селения', 'джаниведено', 'серии', 'терактов', 'использованием', 'заминированных']
#
# Кластер 28: ['выборы', 'всеобщие', 'европарламент', 'костарике', 'очередные', 'германский', 'бундестаг', 'состоялись', 'местные', 'украине', 'национальное', 'собрание', 'вьетнама', 'венгрии', 'зимбабве', 'уругвае', 'эквадоре', 'филиппинах', 'боливии', 'малави']
#
# Кластер 29: ['президентские', 'выборы', 'финляндии', 'мальдивах', 'грузии', 'иране', 'досрочные', 'кыргызстане', 'абхазии', 'мали', 'мадагаскаре', 'повторные', 'ливане', 'республике', 'гаити', 'австрии', 'экваториальной', 'гвинее', 'словении', 'египте', 'состоялись', 'котдивуаре', 'сирии', 'филиппинах', 'кении', 'северной', 'македонии', 'чаде', 'хорватии']
#
# Кластер 30: ['парламентские', 'выборы', 'досрочные', 'президентские', 'островах', 'республике', 'иране', 'сирии', 'таджикистане', 'австрии', 'прошли', 'боснии', 'герцеговине', 'науру', 'чехии', 'белоруссии', 'молдове', 'португалии', 'хорватии', 'литве', 'италии', 'исландии', 'камеруне', 'аргентине', 'мальдивах', 'косове', 'узбекистане', 'азербайджане', 'венесуэле', 'внеочередные']
#
# Кластер 31: ['выборов', 'президентских', 'проведение', 'второй', 'тур', 'парламентских', 'тура', 'первого', 'кыргызстане', 'перу', 'прошл', 'досрочных', 'литве', 'греции', 'таджикистане', 'польше', 'победа', 'леха', 'качиньского', 'республике', 'македонии', 'украине', 'победил', 'левый', 'кандидат', 'ольянта', 'умала', 'абхазии', 'сальвадоре', 'египте']
#
# Кластер 32: ['первый', 'тур', 'выборов', 'президентских', 'прошл', 'франции', 'финляндии', 'словении', 'хорватии', 'республике', 'македонии', 'украине', 'болгарии', 'нигере', 'чили', 'южной', 'осетии', 'парламентских', 'греции']
#
# Кластер 33: ['выборы', 'победу', 'одержала', 'парламентские', 'партия', 'правящая', 'оппозиционная', 'коалиция', 'предварительным', 'данным', 'досрочные', 'народная', 'либеральная', 'социалдемократическая', 'внеочередные', 'эстонии', 'национальная', 'испании', 'фронт', 'альянс', 'прошли', 'реформ', 'финляндии', 'справедливости', 'развития', 'национальный', 'исламистская', 'греции', 'монако', 'албании']
#
# Кластер 34: ['партия', 'выборы', 'парламентские', 'мест', 'правящая', 'большинство', 'лидирует', 'получила', 'победила', 'предварительным', 'данным', 'досрочные', 'парламенте', 'народная', 'социалдемократическая', 'оппозиционная', 'главе', 'выиграла', 'удержала', 'эстонии', 'консервативная', 'латвии', 'нидерландах', 'турции', 'справедливости', 'развития', 'испании', 'однако', 'действующая', 'ликуд']
#
# Кластер 35: ['второй', 'тур', 'выборов', 'победу', 'одержал', 'президента', 'финляндии', 'словакии', 'польши', 'саули', 'ниинисте', 'сербии', 'томислав', 'николич', 'словении', 'бывший', 'премьерминистр', 'страны', 'борут', 'пахор', 'чехии', 'милош', 'земан', 'республики', 'кипр', 'никос', 'анастасиадис', 'самовыдвиженец', 'андрей', 'киска']
#
# Кластер 36: ['второй', 'тур', 'президентских', 'выборов', 'победу', 'одержал', 'аргентине', 'цар', 'болгарии', 'росен', 'плевнелиев', 'мальдивах', 'абдулла', 'ямин', 'гвинеебисау', 'жозе', 'мариу', 'ваш', 'уругвае', 'табаре', 'васкес', 'северном', 'кипре', 'мустафа', 'акынджи', 'гватемале', 'джимми', 'моралес', 'кандидат', 'оппозиции']
#
# Кластер 37: ['стал', 'президентом', 'премьерминистром', 'избран', 'новым', 'японии', 'сиро', 'мори', 'ахмет', 'сезер', 'турции', 'андерс', 'фог', 'расмуссен', 'дании', 'сусило', 'бамбанг', 'юдойоно', 'индонезии', 'джорджо', 'наполитано', 'первым', 'истории', 'италии', 'переизбранным', 'швейцарии', 'дидье', 'буркхальтер', 'ливии', 'ахмед']
#
# Кластер 38: ['премьерминистром', 'стал', 'новым', 'назначен', 'армении', 'эстонии', 'отставку', 'хорватии', 'азербайджана', 'премьерминистра', 'малайзии', 'абдулла', 'артур', 'узбекистана', 'канады', 'италии', 'утверждн', 'чехии', 'египта', 'казахстана', 'абхазии', 'молдовы', 'отставка', 'японии', 'назначение', 'ивицы', 'рачана', 'андраник', 'маргарян', 'али']
#
# Кластер 39: ['президентом', 'избран', 'избрана', 'республики', 'страны', 'парламент', 'избрал', 'венгрии', 'литвы', 'вьетнама', 'турции', 'ахмет', 'сезер', 'иполито', 'мехия', 'доминиканской', 'ференц', 'мадл', 'алехандро', 'толедо', 'перу', 'коллегия', 'выборщиков', 'выбрала', 'арнольда', 'рюйтеля', 'эстонии', 'гырма', 'уольдегиоргис', 'лука']
#
# Кластер 40: ['года', 'премьерминистра', 'пост', 'занял', 'назначен', 'председателя', 'марта', 'апреля', 'боснии', 'герцеговины', 'октября', 'января', 'июня', 'мая', 'сентября', 'сменил', 'посту', 'марио', 'июля', 'февраля', 'президиума', 'гаити', 'совета', 'министров', 'декабря', 'мали', 'сантоме', 'принсипи', 'южной', 'кореи']
#
# Кластер 41: ['года', 'января', 'нефти', 'brent', 'цена', 'марта', 'заявил', 'поста', 'юношеских', 'олимпийских', 'игр', 'сентября', 'доллара', 'баррель', 'директора', 'amazon', 'израиля', 'соглашение', 'гринвичу', 'часы', 'отсчитали', 'миллиардную', 'секунду', 'эры', 'unix', 'которая', 'началась', 'полночь', 'именно', 'момента']
#
# Кластер 42: ['должность', 'президента', 'вступление', 'вступила', 'швейцарии', 'парагвая', 'орасио', 'картеса', 'мустафы', 'акынджи', 'северного', 'кипра', 'маврикия', 'амина', 'гурибфаким', 'дорис', 'лойтхард', 'тринидада', 'тобаго', 'поламэй', 'уикс', 'майя', 'санду', 'молдовы', 'садыра', 'жапарова', 'кыргызстана', 'педро', 'кастильо', 'перу']
#
# Кластер 43: ['космодрома', 'ракетыносителя', 'помощью', 'запущена', 'амс', 'предназначенная', 'исследования', 'канаверал', 'спутника', 'американская', 'запуск', 'дельта', 'луны', 'куру', 'французской', 'гвиане', 'связи', 'космический', 'поиска', 'жизни', 'земли', 'атлас', 'v', 'new', 'horizons', 'плутона', 'phoenix', 'марса', 'танегасима', 'hiia']
#
# Кластер 44: ['вступил', 'должность', 'президент', 'новый', 'египта', 'абхазии', 'молдовы', 'николай', 'тимофти', 'мухаммед', 'мурси', 'мексики', 'энрике', 'пенья', 'ньето', 'ирана', 'хасан', 'рухани', 'мали', 'ибрагим', 'бубакар', 'кейта', 'пакистана', 'мамнун', 'хусейн', 'грузии', 'георгий', 'маргвелашвили', 'мальдив', 'абдулла']
#
# Кластер 45: ['вступил', 'должность', 'президента', 'чехии', 'румынии', 'польши', 'армении', 'гурбангулы', 'бердымухамедов', 'туркменистана', 'алмазбек', 'атамбаев', 'кыргызстана', 'милош', 'земан', 'мадагаскара', 'эри', 'раджаонаримампианина', 'гондураса', 'хуан', 'орландо', 'эрнандес', 'индонезии', 'джоко', 'видодо', 'клаус', 'йоханнис', 'италии', 'серджо', 'маттарелла']
#
# Кластер 46: ['вступил', 'должность', 'президента', 'года', 'января', 'мая', 'декабря', 'леви', 'мванаваса', 'замбии', 'июня', 'каспар', 'филлигер', 'швейцарии', 'энрике', 'боланьос', 'никарагуа', 'георгий', 'пырванов', 'болгарии', 'рикардо', 'мадуро', 'хоэст', 'гондураса', 'марк', 'равалуманана', 'мадагаскарадо', 'марта', 'абель', 'пачеко']
#
# Кластер 47: ['составе', 'союз', 'международной', 'космической', 'станции', 'экипаж', 'мкс', 'тмам', 'старт', 'космического', 'корабля', 'вернулся', 'землю', 'экипажем', 'корабль', 'тимоти', 'международным', 'россиян', 'александра', 'самокутяева', 'елены', 'серовой', 'американца', 'барри', 'уилмора', 'космический', 'стартовал', 'антона', 'шкаплерова', 'саманты']
#
# Кластер 48: ['космодрома', 'ракетыносителя', 'помощью', 'байконур', 'ракетаноситель', 'запущен', 'спутник', 'космический', 'запущена', 'стартовала', 'космического', 'центра', 'танэгасима', 'плесецк', 'аппарат', 'протонм', 'мыс', 'канаверал', 'дельта', 'орбитальная', 'обсерватория', 'swift', 'успешно', 'союзфг', 'межпланетной', 'станцией', 'венера', 'экспресс', 'hiia', 'дзз']
#
# Кластер 49: ['корабля', 'союз', 'экипаж', 'космического', 'составе', 'тма', 'вернулся', 'землю', 'приземление', 'посадки', 'мкс', 'залтин', 'ю', 'старт', 'тмам', 'мс', 'тм', 'старта', 'лончаков', 'франк', 'де', 'винне', 'бельгия', 'ф', 'н', 'юрчихин', 'котов', 'ч', 'шимоньи', 'венгриясша']
#
# Кластер 50: ['сша', 'союз', 'экипаж', 'корабля', 'тма', 'космического', 'старта', 'приземление', 'посадки', 'старт', 'г', 'тмам', 'падалка', 'майкл', 'уильямс', 'япония', 'космодрома', 'байконур', 'ю', 'м', 'д', 'маленченко', 'запуск', 'мкс', 'олег', 'сергей', 'юрий', 'кйперс', 'нидерланды', 'италия']
#
# Кластер 51: ['президента', 'президент', 'отставку', 'страны', 'подал', 'премьерминистр', 'обязанности', 'объявил', 'республики', 'принял', 'парламент', 'ушл', 'молдовы', 'назначен', 'правительства', 'стране', 'парламента', 'суд', 'инаугурация', 'пост', 'года', 'должность', 'италии', 'импичмент', 'решение', 'украины', 'главы', 'арест', 'возложены', 'временно']
#
# Кластер 52: ['украине', 'правления', 'прошла', 'косово', 'отмена', 'смертной', 'казни', 'центральной', 'румынии', 'открыто', 'крупнейшее', 'европе', 'месторождение', 'золота', 'достижение', 'соглашения', 'кндр', 'южной', 'кореей', 'согласно', 'которому', 'последняя', 'обязалась', 'оказать', 'помощь', 'первой', 'сумме', 'млрд', 'евро', 'евреи']
#
# Кластер 53: ['страны', 'парламент', 'решение', 'президент', 'грузии', 'кризис', 'государства', 'заявил', 'советских', 'обмен', 'собственность', 'власти', 'принял', 'информации', 'свободы', 'революцией', 'стала', 'виктора', 'стране', 'конституции', 'причиной', 'годам', 'никарагуа', 'кыргызстана', 'проголосовал', 'переименование', 'отныне', 'официальное', 'наименование', 'кыргызская']
#
# Кластер 54: ['сатурна', 'автоматическая', 'межпланетная', 'станция', 'орбиту', 'успешно', 'космический', 'аппарат', 'лет', 'путешествия', 'системы', 'запуск', 'new', 'horizons', 'изучения', 'зонд', 'компания', 'sun', 'microsystems', 'выпустила', 'ю', 'версию', 'бесплатного', 'офисного', 'пакета', 'openofficeorg', 'марсоход', 'спирит', 'mera', 'спустился']
#
# Кластер 55: ['начало', 'вещания', 'телеканала', 'трансляции', 'судебного', 'процесса', 'работы', 'социальной', 'сети', 'тнт', 'телеигры', 'хочет', 'стать', 'миллионером', 'телеканале', 'орт', 'твс', 'звезда', 'домашний', 'террористом', 'нурпашой', 'кулаевым', 'спас', 'саддамом', 'хусейном', 'рядом', 'сподвижников', 'одноклассники', 'вконтакте', 'популярного']
#
# Кластер 56: ['убийство', 'около', 'городе', 'массовое', 'человек', 'изза', 'также', 'конфликт', 'сша', 'части', 'метеорита', 'км', 'двух', 'город', 'это', 'электроэнергии', 'инцидент', 'газа', 'время', 'произошли', 'христиан', 'тысяч', 'территории', 'атмосферу', 'тонн', 'метров', 'районе', 'позже', 'университета', 'взрыв']
#
# Кластер 57: ['windows', 'microsoft', 'компания', 'открыт', 'всу', 'выход', 'ii', 'контроль', 'apple', 'операционную', 'систему', 'системы', 'the', 'станция', 'освободили', 'убийство', 'лондоне', 'е', 'вещание', 'выпустила', 'первая', 'войска', 'российский', 'открытие', 'полностью', 'компанией', 'военного', 'университета', 'изза', 'великобритании']
#
# Кластер 58: ['православной', 'церкви', 'состоялась', 'премьера', 'нового', 'мюзикла', 'звание', 'автокефалии', 'православная', 'церковь', 'слушаний', 'гаагском', 'суде', 'принят', 'вердикт', 'которому', 'хаварские', 'острова', 'отошли', 'бахрейну', 'отмели', 'фашт', 'аддибаль', 'переданы', 'катару', 'кинофестивале', 'sundance', 'film', 'festival', 'фильма']
#
# Кластер 59: ['самолт', 'погибли', 'boeing', 'борту', 'членов', 'экипажа', 'катастрофа', 'выполнявший', 'рейс', 'упал', 'человек', 'пассажиров', 'авиакомпании', 'крушение', 'разбился', 'пассажирский', 'находившиеся', 'посадку', 'море', 'шесть', 'тегерана', 'врезался', 'air', 'взлте', 'аэропорта', 'города', 'таманрассет', 'алжир', 'потерпел', 'алжирских']
#
# Кластер 60: ['человек', 'погибли', 'результате', 'человека', 'ранены', 'погибло', 'получили', 'ранения', 'около', 'взрыва', 'взрыв', 'городе', 'пострадали', 'погиб', 'землетрясение', 'магнитудой', 'вести', 'теракт', 'города', 'произошло', 'пропали', 'произошл', 'провинции', 'ещ', 'менее', 'индии', 'которого', 'ранено', 'шахте', 'поезд']
#
# Кластер 61: ['погибли', 'человек', 'самолт', 'борту', 'boeing', 'авиакомпании', 'компании', 'человека', 'разбился', 'катастрофа', 'air', 'потерпел', 'самолта', 'крушение', 'находившиеся', 'упал', 'экипажа', 'airlines', 'пассажиров', 'катастрофу', 'членов', 'заходе', 'посадку', 'крупнейшая', 'авиакатастрофа', 'аэропорту', 'взлте', 'врезался', 'гору', 'china']
