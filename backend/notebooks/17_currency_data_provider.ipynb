# %%
from core.currency_data_provider import list_currency_pairs, get_currency_data, get_currency_value_on_date
from core.plot_utils import plot_2d

list_currency_pairs()
# Out:
# ['CNY/RUB', 'EUR/RUB', 'RUB/CNY', 'RUB/EUR', 'RUB/USD', 'USD/RUB']

# %%
pair = "USD/RUB"
df = get_currency_data(pair)
df.head()
# Out:
#         date    value
# 0 2025-09-06  81.5556
# 1 2025-09-05  81.2977
# 2 2025-09-04  80.8488
# 3 2025-09-03  80.5947
# 4 2025-09-02  80.4261

# %%
plot_2d(
    x=df["date"],
    y=df["value"],
    xlabel="Дата",
    ylabel=f"Курс {pair}",
    title=f"Динамика валютной пары {pair}"
)

# %%
get_currency_value_on_date("USD/RUB", "2025-02-24")
# Out:
# 88.1676
